# %% [markdown]
# # Занятие 6.1: Введение в обработку текста
#
# Максим Ионов, [max.ionov@gmail.com](mailto:max.ionov@gmail.com)

# %% [markdown]
# ## 1. Чтение текстов, нужных для упражнений

# %%
import numpy as np
import pandas as pd

# %%
negative = pd.read_csv('negative.csv',delimiter=";")
positive = pd.read_csv('positive.csv',delimiter=";")

# %%
negative.shape
# Out:
# (111923, 12)

# %%
negative.head()
# Out:
#                   tid       tdate            tmane  \
# 0  408906762813579264  1386325944  dugarchikbellko
# 1  408906818262687744  1386325957     nugemycejela
# 2  408906858515398656  1386325966          4post21
# 3  408906914437685248  1386325980         Poliwake
# 4  408906914723295232  1386325980       capyvixowe
#
#                                                ttext  ttype  trep  trtw  tfav  \
# 0  на работе был полный пиддес :| и так каждое за...     -1     0     0     0
# 1  Коллеги сидят рубятся в Urban terror, а я из-з...     -1     0     0     0
# 2  @elina_4post как говорят обещаного три года жд...     -1     0     0     0
# 3  Желаю хорошего полёта и удачной посадки,я буду...     -1     0     0     0
# 4  Обновил за каким-то лешим surf, теперь не рабо...     -1     0     0     0
#
#    tstcount  tfol  tfrien  listcount
# 0      8064   111      94          2
# 1        26    42      39          0
# 2       718    49     249          0
# 3     10628   207     200          0
# 4        35    17      34          0

# %%
positive.shape
# Out:
# (114911, 12)

# %%
positive.head()
# Out:
#                   tid       tdate            tmane  \
# 0  408906692374446080  1386325927  pleease_shut_up
# 1  408906692693221377  1386325927  alinakirpicheva
# 2  408906695083954177  1386325927        EvgeshaRe
# 3  408906695356973056  1386325927    ikonnikova_21
# 4  408906761416867842  1386325943        JumpyAlex
#
#                                                ttext  ttype  trep  trtw  tfav  \
# 0  @first_timee хоть я и школота, но поверь, у на...      1     0     0     0
# 1  Да, все-таки он немного похож на него. Но мой ...      1     0     0     0
# 2  RT @KatiaCheh: Ну ты идиотка) я испугалась за ...      1     0     1     0
# 3  RT @digger2912: "Кто то в углу сидит и погибае...      1     0     1     0
# 4  @irina_dyshkant Вот что значит страшилка :D\nН...      1     0     0     0
#
#    tstcount  tfol  tfrien  listcount
# 0      7569    62      61          0
# 1     11825    59      31          2
# 2      1273    26      27          0
# 3      1549    19      17          0
# 4       597    16      23          1

# %%
alltwits = pd.concat([positive, negative]).sample(frac=1).reset_index(drop=True)
alltwits.shape
# Out:
# (226834, 12)

# %%
alltwits.head()
# Out:
#                   tid       tdate          tmane  \
# 0  410349665616670720  1386669958      PavelNews
# 1  413183007047294976  1387345480  RaspberryPoli
# 2  413730882558918657  1387476103    pinkalina96
# 3  411017763847958528  1386829245      calicinis
# 4  409937067175837696  1386571587      _alex_lol
#
#                                                ttext  ttype  trep  trtw  tfav  \
# 0  “@RadioRecord: Новогодняя ёлка :) #radiorecord...      1     0     0     0
# 1  Даже в школьной столовой стоит елка...а у меня...     -1     0     0     0
# 2  @Kotsubamur прикинь и на мой др моего любимого...     -1     0     0     0
# 3  Сегодня смешал сольники Сержа и Дарона. Получи...      1     0     0     0
# 4  @angggelika13 когда в казань ехали, то нога,  ...      1     0     0     0
#
#    tstcount  tfol  tfrien  listcount
# 0      1615    39     120          0
# 1         3     3       6          0
# 2      1017   877      40          1
# 3       236   201     229          0
# 4     14322  4787      71          3

# %%
alltwits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226834 entries, 0 to 226833
# Data columns (total 12 columns):
# tid          226834 non-null int64
# tdate        226834 non-null int64
# tmane        226834 non-null object
# ttext        226834 non-null object
# ttype        226834 non-null int64
# trep         226834 non-null int64
# trtw         226834 non-null int64
# tfav         226834 non-null int64
# tstcount     226834 non-null int64
# tfol         226834 non-null int64
# tfrien       226834 non-null int64
# listcount    226834 non-null int64
# dtypes: int64(10), object(2)
# memory usage: 20.8+ MB

# %%
alltwits['ttype'].unique()
# Out:
# array([ 1, -1], dtype=int64)

# %%
y = (alltwits['ttype'] + 1) / 2
y.unique()
# Out:
# array([ 1.,  0.])

# %%
from sklearn.model_selection import train_test_split
y_train, y_val, x_train, x_val = train_test_split(y, alltwits.drop(['ttype'], axis=1), test_size=0.2, random_state=42)
x_train.head()
# Out:
#                        tid       tdate            tmane  \
# 107097  410082792744038400  1386606331       ilvina_sh0
# 224163  410839175068667904  1386786667         oqasejuh
# 63992   417324605175390208  1388332914      KaterinaILD
# 108549  416146929635323904  1388052134  Leeenoooooooook
# 67962   409320738642878465  1386424643       esteeroath
#
#                                                     ttext  trep  trtw  tfav  \
# 107097  Рецепты из тетрадки сестре пишу:* \nНа 21 буде...     0     0     0
# 224163  "Владимир Бормотов and Вольдемар Бормотов are ...     0     0     0
# 63992   Кингисеппские цветочные магазины-только наличк...     0     0     0
# 108549   Температура 38.3,очень плохо,буду ждать доктора(     0     0     0
# 67962   ванди - британское говно\n\nтут и про меня ест...     0     0     0
#
#         tstcount  tfol  tfrien  listcount
# 107097      1717    70      92          1
# 224163       227   193     222          0
# 63992        213    11      12          0
# 108549      2614    83      49          0
# 67962       6393   192      85          0

# %%
y_train.head()
# Out:
# 107097    1.0
# 224163    1.0
# 63992     0.0
# 108549    0.0
# 67962     0.0
# Name: ttype, dtype: float64

# %%
x_val.head()
# Out:
#                        tid       tdate            tmane  \
# 215081  413963389724295168  1387531537      Saint_Monro
# 220754  410406890724552704  1386683602  AnnushkaKuzmina
# 60463   408931188813090816  1386331767           edgor_
# 213263  413694539447025664  1387467438         Oshigova
# 113055  412244363625103360  1387121690       Satana6669
#
#                                                     ttext  trep  trtw  tfav  \
# 215081  Ну и как же без сосисок на фоне океана... Посл...     0     0     0
# 220754  Новый год, давай приходи, я уже заждалась:* ht...     0     0     0
# 60463   @edvard146 дочка наверно денег просит в школу:...     0     0     0
# 213263         17 фильмов.... а планшет флешку не видит:(     0     0     0
# 113055  Ааа у меня уже голова болит :((((\nОт этих ибу...     0     0     0
#
#         tstcount  tfol  tfrien  listcount
# 215081      1331   109     105          1
# 220754       372     9      19          0
# 60463       6150  1453    2008         26
# 213263       465   273      27          0
# 113055       317     3      17          0

# %%
y_val.head()
# Out:
# 215081    0.0
# 220754    1.0
# 60463     1.0
# 213263    0.0
# 113055    0.0
# Name: ttype, dtype: float64

# %% [markdown]
# ## 2. Строим частотный список

# %%
import re
import collections

def get_freq_list(texts):
    words = collections.defaultdict(int)
    for text in texts:
        for word in re.split(r'\W', text):
            words[word] += 1
    del words[u'']
    
    return [(word, words[word]) for word in sorted(words, key=lambda w: words[w], reverse=True)]

# %%
get_freq_list(alltwits["ttext"])
# Out:
# [('не', 69730),
#  ('и', 55381),
#  ('я', 53395),
#  ('в', 53034),
#  ('RT', 38076),
#  ('на', 35843),
#  ('что', 33767),
#  ('t', 33227),
#  ('http', 33064),
#  ('co', 33037),
#  ('с', 27383),
#  ('а', 27228),
#  ('меня', 20769),
#  ('то', 20245),
#  ('как', 19462),
#  ('у', 19031),
#  ('D', 17450),
#  ('так', 17054),
#  ('это', 16968),
#  ('мне', 16427),
#  ('все', 15246),
#  ('ты', 13554),
#  ('но', 13083),
#  ('Я', 12683),
#  ('по', 11963),
#  ('за', 11388),
#  ('уже', 10211),
#  ('же', 9700),
#  ('А', 9034),
#  ('ну', 8919),
#  ('только', 8122),
#  ('бы', 8112),
#  ('еще', 7855),
#  ('да', 7715),
#  ('вот', 7406),
#  ('нет', 7253),
#  ('тебя', 7232),
#  ('когда', 6975),
#  ('из', 6659),
#  ('к', 6655),
#  ('очень', 6624),
#  ('день', 6471),
#  ('сегодня', 6428),
#  ('будет', 6411),
#  ('хочу', 6201),
#  ('он', 6130),
#  ('просто', 6091),
#  ('от', 5663),
#  ('было', 5518),
#  ('3', 5516),
#  ('И', 5505),
#  ('тебе', 5493),
#  ('мы', 5470),
#  ('тоже', 5170),
#  ('надо', 4786),
#  ('до', 4772),
#  ('там', 4751),
#  ('даже', 4703),
#  ('его', 4678),
#  ('о', 4569),
#  ('вообще', 4542),
#  ('теперь', 4528),
#  ('есть', 4517),
#  ('если', 4345),
#  ('В', 4253),
#  ('для', 4210),
#  ('кто', 4205),
#  ('завтра', 4094),
#  ('нас', 4078),
#  ('всё', 4045),
#  ('она', 3999),
#  ('могу', 3993),
#  ('Не', 3958),
#  ('Ну', 3913),
#  ('буду', 3811),
#  ('сейчас', 3773),
#  ('Как', 3699),
#  ('2', 3682),
#  ('У', 3617),
#  ('знаю', 3453),
#  ('без', 3376),
#  ('раз', 3309),
#  ('тут', 3301),
#  ('они', 3143),
#  ('люблю', 3142),
#  ('или', 3114),
#  ('почему', 3032),
#  ('ничего', 3030),
#  ('больше', 3022),
#  ('со', 2979),
#  ('Но', 2868),
#  ('про', 2850),
#  ('блин', 2824),
#  ('вы', 2824),
#  ('чем', 2823),
#  ('всегда', 2817),
#  ('С', 2779),
#  ('можно', 2739),
#  ('спасибо', 2718),
#  ('хорошо', 2695),
#  ('мой', 2684),
#  ('Вот', 2677),
#  ('спать', 2652),
#  ('был', 2648),
#  ('дома', 2648),
#  ('потом', 2575),
#  ('время', 2504),
#  ('ещё', 2486),
#  ('их', 2479),
#  ('Это', 2464),
#  ('такой', 2461),
#  ('может', 2433),
#  ('год', 2408),
#  ('делать', 2400),
#  ('где', 2375),
#  ('чтобы', 2328),
#  ('Сегодня', 2284),
#  ('себя', 2252),
#  ('была', 2249),
#  ('этот', 2248),
#  ('ни', 2244),
#  ('быть', 2216),
#  ('всем', 2133),
#  ('Мне', 2126),
#  ('5', 2097),
#  ('после', 2097),
#  ('всех', 2066),
#  ('много', 2066),
#  ('опять', 2057),
#  ('себе', 2009),
#  ('1', 1991),
#  ('Все', 1982),
#  ('вас', 1964),
#  ('хочется', 1947),
#  ('моя', 1935),
#  ('этого', 1925),
#  ('пока', 1924),
#  ('На', 1916),
#  ('такое', 1912),
#  ('лучше', 1909),
#  ('9', 1885),
#  ('хоть', 1874),
#  ('такая', 1873),
#  ('Да', 1871),
#  ('какой', 1864),
#  ('всего', 1836),
#  ('ее', 1829),
#  ('4', 1812),
#  ('такие', 1803),
#  ('Что', 1799),
#  ('один', 1794),
#  ('плохо', 1779),
#  ('нибудь', 1771),
#  ('дня', 1761),
#  ('Так', 1724),
#  ('нужно', 1704),
#  ('настроение', 1695),
#  ('ли', 1694),
#  ('во', 1693),
#  ('под', 1686),
#  ('этом', 1672),
#  ('новый', 1670),
#  ('совсем', 1666),
#  ('домой', 1633),
#  ('него', 1612),
#  ('нам', 1586),
#  ('чего', 1573),
#  ('потому', 1565),
#  ('Спасибо', 1562),
#  ('того', 1553),
#  ('мои', 1547),
#  ('конечно', 1539),
#  ('вам', 1537),
#  ('_', 1532),
#  ('через', 1527),
#  ('кого', 1523),
#  ('скоро', 1511),
#  ('жизни', 1507),
#  ('утро', 1506),
#  ('10', 1485),
#  ('утра', 1476),
#  ('равно', 1471),
#  ('ведь', 1465),
#  ('Ты', 1447),
#  ('люди', 1441),
#  ('ахах', 1424),
#  ('тогда', 1406),
#  ('вчера', 1403),
#  ('никогда', 1395),
#  ('никто', 1391),
#  ('года', 1386),
#  ('жизнь', 1369),
#  ('школу', 1368),
#  ('НЕ', 1339),
#  ('Если', 1326),
#  ('весь', 1324),
#  ('мной', 1323),
#  ('таки', 1320),
#  ('нравится', 1310),
#  ('ж', 1287),
#  ('болит', 1273),
#  ('мама', 1267),
#  ('человек', 1265),
#  ('DD', 1261),
#  ('хотя', 1254),
#  ('Хочу', 1251),
#  ('одна', 1249),
#  ('думаю', 1233),
#  ('эти', 1227),
#  ('Блин', 1210),
#  ('них', 1209),
#  ('вроде', 1208),
#  ('Только', 1205),
#  ('понимаю', 1205),
#  ('моей', 1197),
#  ('х', 1196),
#  ('лет', 1194),
#  ('правда', 1190),
#  ('Завтра', 1190),
#  ('тобой', 1190),
#  ('смотреть', 1186),
#  ('часа', 1177),
#  ('уж', 1174),
#  ('жаль', 1166),
#  ('о_О', 1165),
#  ('кажется', 1162),
#  ('точно', 1162),
#  ('снова', 1154),
#  ('людей', 1151),
#  ('идти', 1148),
#  ('круто', 1147),
#  ('сразу', 1127),
#  ('ему', 1122),
#  ('ахаха', 1122),
#  ('два', 1118),
#  ('Теперь', 1117),
#  ('gt', 1105),
#  ('скучаю', 1103),
#  ('12', 1102),
#  ('О', 1102),
#  ('почти', 1098),
#  ('8', 1093),
#  ('ночь', 1089),
#  ('который', 1086),
#  ('сделать', 1076),
#  ('ночи', 1075),
#  ('сижу', 1073),
#  ('были', 1068),
#  ('чуть', 1068),
#  ('давно', 1055),
#  ('фильм', 1045),
#  ('сильно', 1045),
#  ('бля', 1036),
#  ('Кто', 1033),
#  ('хотела', 1029),
#  ('куда', 1027),
#  ('пойду', 1014),
#  ('какая', 1012),
#  ('вечер', 1003),
#  ('этой', 1003),
#  ('Почему', 996),
#  ('мало', 988),
#  ('думала', 985),
#  ('6', 983),
#  ('всю', 983),
#  ('нельзя', 980),
#  ('Мы', 979),
#  ('улице', 978),
#  ('Когда', 975),
#  ('надеюсь', 959),
#  ('которые', 958),
#  ('её', 958),
#  ('13', 949),
#  ('писать', 942),
#  ('прям', 942),
#  ('lt', 940),
#  ('че', 938),
#  ('будут', 936),
#  ('эту', 936),
#  ('7', 932),
#  ('ладно', 932),
#  ('сама', 932),
#  ('столько', 930),
#  ('минут', 930),
#  ('сказала', 925),
#  ('том', 925),
#  ('наверное', 924),
#  ('раньше', 922),
#  ('кому', 920),
#  ('времени', 920),
#  ('сколько', 918),
#  ('Очень', 913),
#  ('ей', 901),
#  ('11', 899),
#  ('нормально', 899),
#  ('ней', 898),
#  ('свой', 897),
#  ('значит', 896),
#  ('Новый', 891),
#  ('школе', 891),
#  ('каждый', 887),
#  ('15', 885),
#  ('хочет', 879),
#  ('перед', 869),
#  ('тем', 868),
#  ('зачем', 868),
#  ('первый', 868),
#  ('самое', 864),
#  ('долго', 859),
#  ('свою', 858),
#  ('будем', 856),
#  ('ибо', 855),
#  ('тот', 853),
#  ('та', 852),
#  ('кем', 849),
#  ('настроения', 849),
#  ('кстати', 849),
#  ('друг', 848),
#  ('снег', 842),
#  ('самый', 838),
#  ('чтоб', 837),
#  ('вк', 831),
#  ('скучно', 830),
#  ('приятно', 829),
#  ('немного', 828),
#  ('эта', 828),
#  ('посмотреть', 821),
#  ('30', 819),
#  ('фото', 818),
#  ('году', 817),
#  ('сам', 816),
#  ('работу', 811),
#  ('ним', 811),
#  ('ахахах', 805),
#  ('пиздец', 804),
#  ('сказать', 802),
#  ('жалко', 802),
#  ('об', 802),
#  ('такого', 798),
#  ('Он', 794),
#  ('телефон', 793),
#  ('щас', 792),
#  ('привет', 787),
#  ('рождения', 786),
#  ('НГ', 785),
#  ('вместе', 784),
#  ('какие', 782),
#  ('при', 777),
#  ('человека', 773),
#  ('сказал', 772),
#  ('норм', 768),
#  ('ужасно', 765),
#  ('0', 763),
#  ('часов', 754),
#  ('смотрю', 753),
#  ('Всем', 753),
#  ('20', 751),
#  ('нг', 751),
#  ('оно', 748),
#  ('неделю', 748),
#  ('им', 747),
#  ('именно', 747),
#  ('помню', 745),
#  ('давай', 741),
#  ('слишком', 739),
#  ('нее', 738),
#  ('три', 737),
#  ('Надо', 736),
#  ('поняла', 734),
#  ('блять', 733),
#  ('чувство', 728),
#  ('наконец', 725),
#  ('говорит', 725),
#  ('интересно', 724),
#  ('обидно', 722),
#  ('жить', 712),
#  ('жду', 711),
#  ('бывает', 708),
#  ('Вы', 707),
#  ('По', 703),
#  ('знает', 698),
#  ('одной', 698),
#  ('уроки', 698),
#  ('второй', 695),
#  ('никак', 695),
#  ('дела', 692),
#  ('назад', 692),
#  ('стоит', 691),
#  ('видео', 691),
#  ('работает', 690),
#  ('ко', 687),
#  ('быстро', 686),
#  ('чувствую', 685),
#  ('своей', 682),
#  ('знаешь', 682),
#  ('пор', 678),
#  ('рядом', 677),
#  ('недели', 675),
#  ('пришла', 674),
#  ('б', 674),
#  ('боюсь', 671),
#  ('твиттер', 668),
#  ('нету', 668),
#  ('00', 665),
#  ('осталось', 662),
#  ('свои', 662),
#  ('ага', 660),
#  ('пару', 659),
#  ('Нет', 657),
#  ('этим', 656),
#  ('найти', 655),
#  ('утром', 654),
#  ('час', 653),
#  ('главное', 652),
#  ('хватает', 651),
#  ('т', 647),
#  ('лишь', 641),
#  ('Еще', 641),
#  ('Уже', 640),
#  ('туда', 637),
#  ('стало', 637),
#  ('дней', 636),
#  ('сидеть', 634),
#  ('весело', 634),
#  ('з', 633),
#  ('друзья', 633),
#  ('DDD', 630),
#  ('холодно', 629),
#  ('момент', 629),
#  ('Люблю', 628),
#  ('последний', 627),
#  ('забыла', 626),
#  ('ехать', 626),
#  ('голова', 625),
#  ('Меня', 623),
#  ('моего', 621),
#  ('здесь', 621),
#  ('читать', 618),
#  ('Просто', 617),
#  ('работе', 614),
#  ('Доброе', 613),
#  ('пожалуйста', 609),
#  ('грустно', 608),
#  ('сих', 608),
#  ('написать', 607),
#  ('поэтому', 606),
#  ('говорят', 606),
#  ('отлично', 604),
#  ('ой', 603),
#  ('зато', 603),
#  ('реально', 601),
#  ('Даже', 600),
#  ('иногда', 600),
#  ('гулять', 597),
#  ('твит', 595),
#  ('14', 593),
#  ('пошла', 593),
#  ('пол', 592),
#  ('будешь', 584),
#  ('ждать', 584),
#  ('amp', 577),
#  ('За', 576),
#  ('видела', 574),
#  ('дальше', 574),
#  ('страшно', 572),
#  ('хотел', 569),
#  ('мое', 569),
#  ('хочешь', 568),
#  ('вижу', 568),
#  ('работать', 568),
#  ('твой', 564),
#  ('тви', 562),
#  ('получается', 562),
#  ('будто', 562),
#  ('днем', 562),
#  ('таких', 561),
#  ('сделала', 561),
#  ('любимый', 560),
#  ('более', 559),
#  ('снега', 559),
#  ('Всё', 557),
#  ('деньги', 555),
#  ('лень', 554),
#  ('рано', 554),
#  ('глаза', 551),
#  ('ненавижу', 551),
#  ('боль', 550),
#  ('зима', 549),
#  ('вся', 549),
#  ('рада', 548),
#  ('Сейчас', 548),
#  ('обычно', 548),
#  ('те', 547),
#  ('пусть', 547),
#  ('мою', 545),
#  ('особенно', 544),
#  ('капец', 542),
#  ('самом', 541),
#  ('ходить', 541),
#  ('больно', 541),
#  ('целый', 540),
#  ('эх', 539),
#  ('другой', 538),
#  ('походу', 538),
#  ('еду', 538),
#  ('нечего', 538),
#  ('фотки', 532),
#  ('одного', 531),
#  ('выходные', 531),
#  ('своих', 530),
#  ('ЧТО', 529),
#  ('ТЫ', 529),
#  ('скорее', 526),
#  ('любовь', 525),
#  ('сука', 524),
#  ('каникулы', 523),
#  ('понравилось', 521),
#  ('либо', 519),
#  ('хороший', 519),
#  ('подарок', 519),
#  ('нужен', 516),
#  ('вопрос', 515),
#  ('аж', 515),
#  ('идет', 514),
#  ('прости', 513),
#  ('купить', 512),
#  ('дело', 511),
#  ('над', 511),
#  ('нашла', 510),
#  ('устала', 509),
#  ('две', 508),
#  ('работы', 507),
#  ('место', 506),
#  ('придется', 501),
#  ('Она', 497),
#  ('євромайдан', 496),
#  ('моих', 495),
#  ('Мой', 494),
#  ('написала', 492),
#  ('Привет', 491),
#  ('учить', 491),
#  ('Хотя', 491),
#  ('понял', 490),
#  ('одно', 490),
#  ('такую', 490),
#  ('месяц', 487),
#  ('Моя', 484),
#  ('честно', 483),
#  ('сон', 483),
#  ('купила', 483),
#  ('понедельник', 481),
#  ('руки', 480),
#  ('друзей', 480),
#  ('желание', 479),
#  ('кроме', 479),
#  ('вечера', 477),
#  ('ночью', 476),
#  ('Вчера', 475),
#  ('99', 475),
#  ('думал', 475),
#  ('моему', 474),
#  ('МЕНЯ', 473),
#  ('чо', 473),
#  ('кофе', 473),
#  ('кино', 472),
#  ('денег', 472),
#  ('иду', 472),
#  ('типа', 471),
#  ('вставать', 471),
#  ('класс', 470),
#  ('правильно', 470),
#  ('Бля', 468),
#  ('песни', 467),
#  ('погода', 467),
#  ('вечером', 466),
#  ('декабря', 465),
#  ('нового', 464),
#  ('хуже', 463),
#  ('парень', 463),
#  ('Жаль', 462),
#  ('К', 461),
#  ('День', 460),
#  ('России', 459),
#  ('деле', 459),
#  ('говорить', 455),
#  ('Мама', 455),
#  ('любит', 453),
#  ('слова', 453),
#  ('мир', 449),
#  ('пора', 449),
#  ('самая', 448),
#  ('чай', 446),
#  ('Опять', 446),
#  ('смогу', 443),
#  ('друга', 443),
#  ('могла', 440),
#  ('собой', 440),
#  ('начала', 440),
#  ('пишу', 440),
#  ('Сижу', 436),
#  ('несколько', 434),
#  ('постоянно', 434),
#  ('экзамен', 433),
#  ('видимо', 432),
#  ('НА', 431),
#  ('своего', 430),
#  ('самого', 428),
#  ('вместо', 428),
#  ('Эх', 427),
#  ('Надеюсь', 427),
#  ('наверно', 426),
#  ('меньше', 426),
#  ('пойти', 425),
#  ('делаю', 425),
#  ('пишет', 424),
#  ('чувак', 422),
#  ('раза', 419),
#  ('нужна', 418),
#  ('папа', 418),
#  ('наш', 418),
#  ('таким', 418),
#  ('др', 417),
#  ('сердце', 417),
#  ('часто', 417),
#  ('https', 417),
#  ('ааа', 414),
#  ('Какой', 414),
#  ('должна', 411),
#  ('удачи', 411),
#  ('можешь', 411),
#  ('вдруг', 411),
#  ('соскучилась', 410),
#  ('голову', 410),
#  ('твои', 408),
#  ('бесит', 408),
#  ('короче', 407),
#  ('смешно', 407),
#  ('сказали', 406),
#  ('Может', 405),
#  ('проснулась', 405),
#  ('решила', 405),
#  ('доброе', 404),
#  ('100', 404),
#  ('школы', 401),
#  ('стал', 400),
#  ('знала', 400),
#  ('хд', 399),
#  ('После', 399),
#  ('музыку', 398),
#  ('тех', 398),
#  ('этих', 398),
#  ('хорошего', 397),
#  ('какое', 397),
#  ('голос', 397),
#  ('счастья', 396),
#  ('обратно', 396),
#  ('КАК', 396),
#  ('ноги', 395),
#  ('Скоро', 395),
#  ('голове', 394),
#  ('То', 394),
#  ('видел', 394),
#  ('одну', 393),
#  ('Год', 393),
#  ('своим', 393),
#  ('сезон', 392),
#  ('Пока', 392),
#  ('получилось', 392),
#  ('играть', 390),
#  ('сделал', 389),
#  ('ЭТО', 388),
#  ('ужас', 388),
#  ('До', 388),
#  ('могут', 386),
#  ('концерт', 385),
#  ('супер', 385),
#  ('хорошая', 384),
#  ('сначала', 383),
#  ('получится', 381),
#  ('интернет', 379),
#  ('ахахаха', 378),
#  ('сожалению', 377),
#  ('субботу', 377),
#  ('слово', 377),
#  ('любви', 376),
#  ('похоже', 375),
#  ('наши', 374),
#  ('ок', 373),
#  ('ними', 373),
#  ('скучать', 372),
#  ('обожаю', 372),
#  ('даа', 371),
#  ('обязательно', 370),
#  ('понятно', 370),
#  ('заболела', 370),
#  ('действительно', 369),
#  ('самые', 368),
#  ('этому', 367),
#  ('месте', 367),
#  ('МНЕ', 366),
#  ('Они', 365),
#  ('мило', 365),
#  ('истории', 363),
#  ('сложно', 363),
#  ('город', 362),
#  ('забыл', 362),
#  ('общем', 361),
#  ('девушка', 361),
#  ('сериал', 360),
#  ('подарки', 360),
#  ('нашей', 360),
#  ('мысли', 359),
#  ('лох', 359),
#  ('последнее', 359),
#  ('сходить', 358),
#  ('везде', 358),
#  ('оказывается', 357),
#  ('знать', 357),
#  ('снов', 356),
#  ('серия', 356),
#  ('твиттере', 355),
#  ('против', 355),
#  ('далеко', 355),
#  ('моим', 355),
#  ('ох', 355),
#  ('умею', 354),
#  ('неё', 353),
#  ('пары', 352),
#  ('лето', 352),
#  ('смотрела', 351),
#  ('говно', 350),
#  ('шк', 349),
#  ('любимая', 348),
#  ('происходит', 346),
#  ('делаешь', 346),
#  ('должен', 346),
#  ('ваще', 346),
#  ('боже', 345),
#  ('написал', 345),
#  ('НУ', 345),
#  ('печально', 345),
#  ('печаль', 344),
#  ('болеть', 344),
#  ('радует', 344),
#  ('видно', 344),
#  ('странно', 344),
#  ('которая', 344),
#  ('лента', 343),
#  ('песня', 343),
#  ('настолько', 343),
#  ('дом', 342),
#  ('ума', 341),
#  ('прямо', 341),
#  ('дни', 341),
#  ('зря', 341),
#  ('молодец', 340),
#  ('поздно', 339),
#  ('A', 339),
#  ('вспомнила', 339),
#  ('Хорошо', 338),
#  ('пить', 337),
#  ('понять', 337),
#  ('песню', 336),
#  ('стала', 336),
#  ('работа', 336),
#  ('безумно', 334),
#  ('Из', 334),
#  ('читаю', 334),
#  ('увидела', 333),
#  ('проблемы', 333),
#  ('16', 332),
#  ('л', 331),
#  ('стыдно', 330),
#  ('ТАК', 330),
#  ('хватит', 330),
#  ('иди', 329),
#  ('никуда', 329),
#  ('людям', 327),
#  ('шоке', 327),
#  ('ради', 327),
#  ('Или', 326),
#  ('говорю', 326),
#  ('каток', 326),
#  ('брат', 326),
#  ('ДА', 325),
#  ('никого', 324),
#  ('TukvaSociopat', 323),
#  ('слушаю', 323),
#  ('лол', 322),
#  ('Кстати', 322),
#  ('метро', 322),
#  ('кот', 321),
#  ('конец', 321),
#  ('лучший', 320),
#  ('Ох', 319),
#  ('какую', 319),
#  ('успела', 319),
#  ('одни', 319),
#  ('увидеть', 319),
#  ('посмотрела', 318),
#  ('видеть', 318),
#  ('любишь', 318),
#  ('большое', 318),
#  ('Где', 317),
#  ('классно', 317),
#  ('Есть', 315),
#  ('праздник', 315),
#  ('18', 315),
#  ('ощущение', 315),
#  ('забыть', 314),
#  ('девушки', 314),
#  ('городе', 314),
#  ('крутой', 313),
#  ('взять', 313),
#  ('месяца', 313),
#  ('волосы', 313),
#  ('вещи', 312),
#  ('родители', 312),
#  ('пятницу', 311),
#  ('никому', 310),
#  ('тому', 310),
#  ('счастье', 310),
#  ('Зачем', 309),
#  ('плакать', 309),
#  ('неделя', 309),
#  ('выходных', 309),
#  ('вокруг', 309),
#  ('школа', 308),
#  ('оч', 308),
#  ('50', 307),
#  ('верю', 307),
#  ('часть', 307),
#  ('называется', 306),
#  ('Там', 306),
#  ('40', 306),
#  ('хотелось', 306),
#  ('недавно', 306),
#  ('красиво', 306),
#  ('девочка', 305),
#  ('дети', 305),
#  ('урок', 303),
#  ('лицо', 303),
#  ('января', 303),
#  ('новости', 302),
#  ('зачет', 302),
#  ('подруга', 302),
#  ('слушать', 302),
#  ('Москве', 301),
#  ('какого', 301),
#  ('НО', 301),
#  ('узнала', 301),
#  ('Q', 300),
#  ('понимаешь', 299),
#  ('вами', 298),
#  ('Боже', 298),
#  ('между', 298),
#  ('горло', 297),
#  ('умер', 297),
#  ('мамой', 297),
#  ('нахуй', 297),
#  ('ВСЕ', 296),
#  ('черт', 296),
#  ('например', 293),
#  ('температура', 293),
#  ('нами', 293),
#  ('сюда', 293),
#  ('З', 292),
#  ('пишут', 292),
#  ('ребят', 291),
#  ('делает', 291),
#  ('пошел', 290),
#  ('Ненавижу', 290),
#  ('тяжело', 290),
#  ('двух', 289),
#  ('новогоднего', 289),
#  ('возможно', 289),
#  ('твоя', 289),
#  ('купил', 289),
#  ('игры', 288),
#  ('Вам', 288),
#  ('хорошее', 287),
#  ('милый', 287),
#  ('хотят', 286),
#  ('большой', 286),
#  ('любить', 286),
#  ('Буду', 286),
#  ('Рождения', 286),
#  ('говорила', 286),
#  ('учиться', 285),
#  ('новые', 285),
#  ('мог', 284),
#  ('готова', 284),
#  ('нь', 284),
#  ('Жизнь', 284),
#  ('хаха', 284),
#  ('начинается', 284),
#  ('конце', 283),
#  ('Ахаха', 282),
#  ('сами', 282),
#  ('дааа', 282),
#  ('конца', 282),
#  ('музыка', 281),
#  ('самой', 281),
#  ('сделали', 280),
#  ('пять', 280),
#  ('Наконец', 279),
#  ('прошло', 279),
#  ('спокойной', 279),
#  ('итоге', 278),
#  ('ребята', 278),
#  ('танцы', 278),
#  ('слов', 278),
#  ('вечно', 277),
#  ('Россия', 277),
#  ('улицу', 276),
#  ('2014', 276),
#  ('думать', 275),
#  ('сплю', 275),
#  ('серии', 274),
#  ('решил', 274),
#  ('нужны', 273),
#  ('Вообще', 273),
#  ('проблема', 273),
#  ('подряд', 273),
#  ('номер', 272),
#  ('пришлось', 272),
#  ('выспалась', 272),
#  ('маме', 272),
#  ('2013', 272),
#  ('сессия', 272),
#  ('классе', 271),
#  ('го', 271),
#  ('начал', 270),
#  ('скажу', 270),
#  ('любимые', 270),
#  ('уснуть', 270),
#  ('последние', 269),
#  ('нем', 269),
#  ('дура', 269),
#  ('гости', 269),
#  ('своими', 268),
#  ('кушать', 268),
#  ('болею', 268),
#  ('пошли', 267),
#  ('P', 266),
#  ('любимого', 265),
#  ('история', 265),
#  ('письмо', 265),
#  ('твиты', 265),
#  ('фигня', 265),
#  ('От', 265),
#  ('Хоть', 265),
#  ('идиот', 265),
#  ('магазин', 264),
#  ('ем', 264),
#  ('шо', 263),
#  ('красивая', 263),
#  ('хорошие', 262),
#  ('знал', 262),
#  ('сидит', 262),
#  ('последняя', 262),
#  ('говорил', 262),
#  ('тему', 261),
#  ('Интересно', 260),
#  ('дали', 260),
#  ('классный', 260),
#  ('дождь', 260),
#  ('пришел', 259),
#  ('тож', 259),
#  ('o_O', 259),
#  ('зиму', 259),
#  ('Зато', 259),
#  ('планы', 258),
#  ('всей', 258),
#  ('увы', 258),
#  ('ппц', 257),
#  ('прекрасно', 257),
#  ('ура', 256),
#  ('ооо', 256),
#  ('фу', 256),
#  ('аааа', 256),
#  ('Для', 255),
#  ('летом', 255),
#  ('одном', 255),
#  ('которых', 254),
#  ('девочки', 254),
#  ('е', 254),
#  ('мире', 253),
#  ('откуда', 253),
#  ('свое', 253),
#  ('сдавать', 253),
#  ('случилось', 253),
#  ('жесть', 253),
#  ('ответ', 253),
#  ('Ой', 252),
#  ('спокойно', 251),
#  ('рад', 251),
#  ('любимой', 251),
#  ('детей', 251),
#  ('воскресенье', 251),
#  ...]

# %% [markdown]
# ## 3. Bag of words

# %% [markdown]
# ### 3.1. CountVectorizer

# %%
import sklearn.feature_extraction.text

# %%
vctr = sklearn.feature_extraction.text.CountVectorizer()

# %%
X_train_counts = vctr.fit_transform(alltwits["ttext"])

# %%
X_train_counts.shape
# Out:
# (226834, 294601)

# %%
vctr
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vctr.vocabulary_
# Out:
# {'radiorecord': 90353,
#  'новогодняя': 206119,
#  'ёлка': 293842,
#  'http': 47493,
#  'co': 26881,
#  'fj47y2utc0': 39689,
#  'ужас': 274057,
#  'даже': 152175,
#  'школьной': 289094,
#  'столовой': 262594,
#  'стоит': 262503,
#  'елка': 160694,
#  'меня': 192973,
#  'еще': 161155,
#  'попыток': 230397,
#  'не': 202151,
#  'было': 135886,
#  'kotsubamur': 59817,
#  'прикинь': 235724,
#  'на': 197876,
#  'мой': 195286,
#  'др': 158326,
#  'моего': 195163,
#  'любимого': 189194,
#  'будет': 135032,
#  'сегодня': 252292,
#  'смешал': 256686,
#  'сольники': 258612,
#  'сержа': 253114,
#  'дарона': 152540,
#  'получил': 228849,
#  'что': 287274,
#  'то': 268884,
#  'типа': 268595,
#  'нового': 206092,
#  'альбома': 124437,
#  'соад': 257511,
#  'angggelika13': 16032,
#  'когда': 179334,
#  'казань': 175091,
#  'ехали': 161095,
#  'нога': 206260,
#  'спина': 260338,
#  'фары': 278394,
#  'глаза': 148513,
#  'rt': 93089,
#  'vsuetin': 112916,
#  'afanasybiz': 11610,
#  'изначально': 171858,
#  'планировалась': 222965,
#  'выставка': 146068,
#  'конфет': 181024,
#  'но': 206003,
#  'внучка': 140845,
#  'устроителей': 276785,
#  'их': 174388,
#  'стрескала': 263123,
#  'понравилось': 229654,
#  'типс': 268657,
#  'перезаписал': 220019,
#  'песни': 221325,
#  'пацан': 218838,
#  'ахуевший': 127659,
#  'опять': 212712,
#  'лямыч': 189642,
#  'всех': 143221,
#  'заткнул': 168258,
#  'yuliakiruhina': 119102,
#  'хочу': 283394,
#  'подоконник': 225812,
#  'бодягиной': 132969,
#  'екатерине': 160610,
#  'юрьевне': 292695,
#  'red_penguinnn': 91043,
#  'мне': 194783,
#  'кажется': 175035,
#  'народ': 200601,
#  'реально': 245915,
#  'слишком': 255933,
#  'наглеет': 198394,
#  'm9484x9ad5i7m89': 67762,
#  'умею': 275116,
#  'говорить': 149088,
#  'нет': 204815,
#  'поэтому': 233088,
#  'происходит': 238518,
#  'полёт': 229026,
#  'фантазии': 278230,
#  'отмазываюсь': 215072,
#  'от': 213872,
#  'погулять': 224767,
#  'со': 257507,
#  'стрёмным': 263362,
#  'парнем': 218313,
#  'спорт': 260667,
#  'зима': 169792,
#  'кузбасс': 184345,
#  'олимпийский': 211569,
#  'год': 149136,
#  'для': 155915,
#  'нас': 200773,
#  'wstk1reuhj': 115077,
#  'приятно': 237086,
#  'быть': 135966,
#  'чьим': 287723,
#  'куском': 185006,
#  'счастья': 264848,
#  'тепла': 267883,
#  'любви': 189133,
#  'заботы': 163476,
#  'boo': 23138,
#  'tifull': 104454,
#  'новое': 206130,
#  'представление': 234092,
#  'красоте': 182911,
#  'рот': 248609,
#  'ноги': 206272,
#  '27': 2635,
#  'наконец': 199443,
#  'поняла': 229712,
#  'очевидные': 217029,
#  'вещи': 138754,
#  'реальность': 245921,
#  'жестока': 162028,
#  'да': 151906,
#  'другой': 158647,
#  'стороны': 262728,
#  'понимая': 229622,
#  'мы': 197283,
#  'можем': 195188,
#  'ими': 172392,
#  'управлять': 275898,
#  'appleiam91': 17773,
#  'есть': 161026,
#  'тут': 271803,
#  'личности': 187946,
#  'поведение': 224079,
#  'которых': 182299,
#  'огорчает': 210121,
#  'mishakrupin': 72712,
#  'это': 292021,
#  'комплимент': 180389,
#  'или': 172183,
#  'сарказм': 250606,
#  'врубаюсь': 142977,
#  'немного': 203632,
#  'переводчик': 219646,
#  'google': 43625,
#  'лучшая': 188922,
#  'покупка': 228023,
#  'откройте': 214801,
#  'вставить': 143436,
#  'vista': 111575,
#  'работает': 242102,
#  'funnyhoorse': 41215,
#  'ну': 206989,
#  'случается': 256229,
#  'некоторыми': 203402,
#  'вообще': 141873,
#  'доолго': 157470,
#  'спорить': 260657,
#  'можно': 195212,
#  'например': 200296,
#  'гавно': 146851,
#  'пишет': 222758,
#  'тви': 266898,
#  'он': 211790,
#  'норм': 206550,
#  'так': 265932,
#  'самый': 250335,
#  'любимый': 189228,
#  'мальчик': 190740,
#  'больше': 133568,
#  'никто': 205588,
#  'нужен': 207049,
#  'люблю': 189272,
#  'его': 160281,
#  'очень': 217054,
#  'vrudxhemws': 112820,
#  'все': 143048,
#  'будут': 135095,
#  'вечером': 138654,
#  'сидеть': 253621,
#  'вк': 140063,
#  'настя': 201285,
#  'смотреть': 256917,
#  '2е': 3204,
#  'ги': 148121,
#  'спасибо': 259984,
#  'ромке': 248392,
#  'умудрился': 275320,
#  'найти': 199242,
#  'хорошем': 283127,
#  'качестве': 177071,
#  'ему': 160783,
#  'благодарна': 131991,
#  'luxurybitches': 67230,
#  'ой': 210993,
#  'наташа': 201390,
#  'теперь': 267874,
#  'знаю': 170222,
#  'alertundertaker': 12933,
#  'до': 156058,
#  'числа': 286817,
#  'думаю': 158987,
#  'успею': 276535,
#  'tonn_pavloff': 105315,
#  'm1ff16': 67622,
#  'братан': 134282,
#  'ахуенная': 127672,
#  'кнопка': 179159,
#  'черный': 286305,
#  'список': 260400,
#  'нам': 199735,
#  'спасти': 260068,
#  'эти': 291990,
#  'души': 159319,
#  'кинь': 178046,
#  'лучше': 188924,
#  'номер': 206413,
#  'дм': 155919,
#  'bajlepa_': 20440,
#  'ты': 271952,
#  'лыс': 188995,
#  'столько': 262613,
#  'брутален': 134798,
#  'короче': 181780,
#  'ни': 205261,
#  'разу': 243933,
#  'брюс': 134868,
#  'уиллис': 274344,
#  'harrystylesaww': 45616,
#  'скучала': 255372,
#  'милая': 193863,
#  'просто': 239630,
#  'учеба': 277515,
#  'редко': 246268,
#  'захожу': 168661,
#  'рада': 242268,
#  'помнишь': 229267,
#  'nichijou': 78824,
#  'адов': 122940,
#  'бредогон': 134433,
#  'зачем': 168778,
#  'начал': 201831,
#  'как': 175234,
#  'же': 161647,
#  'хорошо': 283157,
#  'учиться': 277659,
#  'во': 140867,
#  'вторник': 143769,
#  'xd': 115792,
#  'правда': 233245,
#  'хотят': 283288,
#  'убить': 272842,
#  'небо': 202231,
#  'голубое': 149486,
#  'вода': 140931,
#  'мокрая': 195330,
#  'солнце': 258535,
#  'яркое': 293544,
#  'жизнь': 162289,
#  'говно': 148993,
#  'dyakovanastasia': 34300,
#  'ахахха': 127436,
#  'там': 266198,
#  'миллион': 193948,
#  'раз': 242464,
#  'пересдавала': 220649,
#  'здесь': 169421,
#  'охото': 216759,
#  'равно': 242223,
#  'уровень': 276132,
#  'позвонил': 227138,
#  'юрка': 292665,
#  'поговорили': 224622,
#  'хотел': 283242,
#  'бы': 135811,
#  'вышла': 146535,
#  'получается': 228802,
#  'спрятаться': 260920,
#  'своем': 251633,
#  'маленьком': 190538,
#  'мире': 194365,
#  'нужно': 207063,
#  'каждое': 175017,
#  'утро': 277116,
#  'буду': 135090,
#  'читать': 286959,
#  'мантру': 191139,
#  'житьотдельножитьотдельножитьотдельно': 162541,
#  'miramd_24': 72572,
#  'американская': 124639,
#  'история': 174175,
#  'ужасов': 274105,
#  'шикарный': 288768,
#  'сериал': 253120,
#  'каждый': 175026,
#  'сезон': 252372,
#  'по': 223761,
#  'своему': 251634,
#  'интересен': 172993,
#  'блиин': 132309,
#  'идеальный': 171144,
#  'fmnwc43ys1': 39991,
#  'песня': 221331,
#  'крутая': 183865,
#  'наргиз': 200452,
#  'аааааааа': 121744,
#  'голос': 149406,
#  'кто': 184198,
#  'нить': 205754,
#  'знает': 170058,
#  'почему': 232750,
#  'наши': 202040,
#  'дата': 152597,
#  'центры': 285056,
#  'такие': 265966,
#  'адские': 122995,
#  'цены': 285058,
#  'ломят': 188421,
#  'расстроен': 245176,
#  'herojake': 46231,
#  'блин': 132318,
#  'пожалуйста': 226862,
#  'щенячьи': 290255,
#  'глазки': 148539,
#  'сверху': 251267,
#  'соседей': 259165,
#  'такой': 266008,
#  'грохот': 150936,
#  'жду': 161621,
#  'они': 211835,
#  'через': 286155,
#  'потолок': 232081,
#  'ко': 179200,
#  'провалятся': 237406,
#  'somibemic': 99202,
#  'похоже': 232577,
#  'только': 269244,
#  'чувак': 287362,
#  'упоротый': 275842,
#  'аниме': 125261,
#  'тем': 267673,
#  'заметила': 166214,
#  'номере': 206418,
#  'love': 66455,
#  'child': 26102,
#  'даррен': 152543,
#  'был': 135871,
#  'ангелочком': 125004,
#  'символично': 253834,
#  '__': 8341,
#  'imgrean': 49641,
#  'возвращением': 141156,
#  'таки': 265963,
#  'иже': 171305,
#  'скучали': 255376,
#  'тебе': 267306,
#  'i_korotchenko': 48191,
#  'пока': 227584,
#  'уничтожают': 275511,
#  'наших': 202053,
#  'граждан': 150384,
#  'москве': 196096,
#  'позже': 227275,
#  'просыпаюсь': 239747,
#  'братиславе': 134307,
#  'соответственно': 258909,
#  'утра': 277065,
#  'anka_anechka': 16204,
#  'се': 252191,
#  'будешь': 135037,
#  'двоих': 152901,
#  'успокаивать': 276549,
#  'shukina_nastya3': 97320,
#  'за': 163127,
#  'письмо': 222543,
#  'скоро': 254960,
#  'придет': 235289,
#  'жди': 161613,
#  'сменилась': 256572,
#  'голове': 149305,
#  'welcome': 114006,
#  'to': 105039,
#  'the': 103973,
#  'machine': 67949,
#  'круто': 183901,
#  'музыкантом': 196761,
#  'свой': 251652,
#  'плеер': 223274,
#  'elena_skyyy': 35895,
#  'about_me09': 11046,
#  'падший': 217539,
#  'человек': 285951,
#  'холопом': 282898,
#  'назвал': 198948,
#  'ладно': 185611,
#  'госпожа': 150140,
#  'сейчас': 252418,
#  'духе': 159254,
#  'бляха': 132666,
#  'муха': 197129,
#  'проигрывают': 238413,
#  'эх': 292157,
#  'lifenews_ru': 64574,
#  'oleggazmanov': 82176,
#  'постарел': 231551,
#  'газманов': 147019,
#  'всё': 143683,
#  'девчонки': 153326,
#  'пропали': 239044,
#  'делать': 153697,
#  'переживать': 219964,
#  'наслаждаться': 200863,
#  'одиночеством': 210490,
#  'strikkeg': 100714,
#  'romarius88': 92598,
#  'всеми': 143148,
#  'подружками': 226147,
#  'ромы': 248409,
#  'весело': 138385,
#  'сашка': 250792,
#  'прости': 239590,
#  'прийти': 235663,
#  'дурацкие': 159071,
#  'анкетыыыы': 125308,
#  'выздоравливай': 144809,
#  'скорее': 254943,
#  'lt': 66813,
#  'какими': 175313,
#  'долбоёбами': 157053,
#  'мои': 195267,
#  'одноклассники': 210621,
#  'были': 135882,
#  'хорошие': 283140,
#  'ленте': 186729,
#  'могу': 195039,
#  'спокойно': 260587,
#  'взгляд': 138901,
#  'снизу': 257298,
#  'урганта': 276082,
#  'kotopakxi1': 59791,
#  'natali1949': 77478,
#  'вчера': 144026,
#  'внезапно': 140710,
#  'электричество': 291147,
#  'закончилось': 165620,
#  'pwp0blabkj': 88609,
#  'trevel2000': 105756,
#  'позорище': 227406,
#  'уважаемый': 272955,
#  'мамонтов': 190886,
#  'вопрос': 141964,
#  'назначил': 199000,
#  'сердюкова': 253031,
#  'говорит': 149084,
#  'важно': 136555,
#  'сказать': 254391,
#  'мог': 195010,
#  'вам': 136844,
#  'плюют': 223679,
#  'спину': 260358,
#  'значит': 170201,
#  'вы': 144128,
#  'впереди': 142612,
#  'если': 160970,
#  'суп': 264056,
#  'живете': 162120,
#  'коммуналке': 180236,
#  'of2d1zd9lh': 81537,
#  'разделе': 243137,
#  'фото': 279938,
#  'amp': 14981,
#  'gt': 44453,
#  'lesbian': 63981,
#  'couple': 27373,
#  'первые': 219445,
#  '34': 3443,
#  'фоток': 280021,
#  'фотки': 279926,
#  'джастина': 154675,
#  'бибера': 131455,
#  'селены': 252595,
#  'o_o': 81146,
#  'коробку': 181653,
#  'испортил': 173893,
#  'малыш': 190677,
#  'простит': 239605,
#  'улице': 274773,
#  'хоооолоооднооо': 283009,
#  'такая': 265944,
#  'тепло': 267900,
#  'люббивая': 189129,
#  'pashkenziy': 84901,
#  'shoom_m': 97229,
#  'интересно': 173007,
#  'вадику': 136512,
#  'привет': 234911,
#  'удачи': 273675,
#  'maeksa': 68109,
#  'гражданском': 150404,
#  'праве': 233267,
#  'успешной': 276524,
#  'сдачи': 252000,
#  'pitnistya_zebr': 86225,
#  'нихуяшенки': 205820,
#  'дамочка': 152369,
#  'понимаете': 229596,
#  'машинка': 192191,
#  'ваша': 137318,
#  'челюсть': 286017,
#  'пойдёт': 227543,
#  'погуляет': 224755,
#  'соседней': 259176,
#  'праздничное': 233448,
#  'настроение': 201151,
#  'настольгия': 201084,
#  'лету': 187060,
#  'вспомнить': 143365,
#  'потом': 232088,
#  'плакать': 222914,
#  'честно': 286428,
#  'hyun_persik': 47838,
#  'вот': 142491,
#  'надо': 198665,
#  'она': 211792,
#  'действенная': 153561,
#  'dd': 30402,
#  'воду': 141029,
#  'рисом': 247557,
#  'начали': 201836,
#  'barvikha': 20794,
#  'family': 38587,
#  'ovrha30raz': 83921,
#  'gregwest_': 44162,
#  'заткнись': 168255,
#  'продолжай': 238052,
#  'стонала': 262645,
#  'гладила': 148491,
#  'грега': 150607,
#  'kristinabozdina': 60410,
#  'tutinaalla': 106293,
#  'vviksya': 113071,
#  'заебала': 164830,
#  'ныть': 207271,
#  'уже': 274132,
#  'siqygalanuw': 97786,
#  'googe': 43624,
#  'ума': 275006,
#  'hs5k5s7qta': 47434,
#  'скромняги': 255185,
#  'vesti_news': 110465,
#  'фмс': 279531,
#  'насчитало': 201306,
#  'россии': 248508,
#  'миллиона': 193949,
#  'нелегалов': 203468,
#  'azc0bozhwv': 19891,
#  'срочно': 261242,
#  'ттотт': 271336,
#  'подъюбник': 226649,
#  'цури': 285323,
#  'забыла': 163590,
#  'всегда': 143069,
#  'походу': 232568,
#  'новый': 206240,
#  'ульянкой': 274971,
#  'накрылся': 199569,
#  'insidious_gay': 50096,
#  'нужны': 207075,
#  'русские': 249122,
#  'little': 65288,
#  'monsters': 73675,
#  'лента': 186717,
#  'помоги': 229293,
#  'историю': 174173,
#  'происхождения': 238530,
#  'таджиков': 265786,
#  'откуда': 214882,
#  'смеются': 256751,
#  'aaxweskvcp': 10926,
#  'всем': 143142,
#  'твиттерским': 267071,
#  'доброго': 156240,
#  'дня': 156046,
#  'зз': 169754,
#  'oiseau_leila': 81807,
#  'скинула': 254726,
#  'сказала': 254366,
#  'скинет': 254715,
#  'сама': 250005,
#  'дождаться': 156683,
#  'совсем': 258014,
#  'никаких': 205459,
#  'сил': 253716,
#  'руки': 248925,
#  'опускаются': 212627,
#  'никакие': 205456,
#  'уговоры': 273378,
#  'про': 237148,
#  'всего': 143085,
#  'один': 210436,
#  'день': 153976,
#  'помогают': 229292,
#  'разработать': 243773,
#  'мероприятие': 193134,
#  'мс': 196443,
#  'реферат': 247085,
#  'рммп': 247688,
#  'отзывы': 214591,
#  'фестивалях': 278731,
#  'конспекты': 180786,
#  'семинаров': 252746,
#  'подготовка': 225105,
#  'кр': 182591,
#  'ох': 216657,
#  'этот': 292077,
#  'вечер': 138614,
#  'закончился': 165623,
#  'ура': 275993,
#  'fawasefejepi': 38790,
#  'из': 171314,
#  'зеленограда': 169608,
#  'москвы': 196113,
#  'елку': 160705,
#  'доставал': 157910,
#  'подписал': 225909,
#  'кило': 177863,
#  'макулатуры': 190464,
#  'поезде': 226771,
#  'почитал': 232837,
#  'где': 147615,
#  'расписывался': 244651,
#  'smaterazzo': 98469,
#  'lisagoldyes': 65176,
#  'война': 141421,
#  'будто': 135089,
#  'шее': 288438,
#  'дырку': 159417,
#  'прирезали': 236436,
#  'туда': 271391,
#  'засыпали': 168154,
#  'какую': 175381,
#  'хрень': 283562,
#  'таком': 266012,
#  'плане': 222948,
#  'фуу': 280618,
#  'урааа': 275996,
#  '21': 2400,
#  '00': 0,
#  'иду': 171261,
#  'фильм': 279094,
#  'вандюх': 136897,
#  'показывали': 227657,
#  'земля': 169663,
#  'конечно': 180633,
#  'обязательно': 209859,
#  'должна': 157142,
#  'ещё': 161169,
#  'водитель': 140951,
#  '129': 1007,
#  'маршрутке': 191565,
#  'рассказывает': 244957,
#  'истории': 174144,
#  'жизни': 162284,
#  'весёлый': 138525,
#  'общительный': 209585,
#  'stasiyagregory': 100257,
#  'мама': 190801,
#  'банан': 128891,
#  'впитался': 142683,
#  'кости': 182049,
#  'быстро': 135933,
#  'съела': 265011,
#  'tenthonelove': 103687,
#  'jezzzinsky': 52896,
#  'ахахахах': 127266,
#  'поздоровайся': 227186,
#  'мерчиком': 193186,
#  'chistolenta': 26160,
#  'зая': 169014,
#  'отменяю': 215117,
#  'премьеру': 234446,
#  'фильма': 279095,
#  'pussy': 88480,
#  'riot': 91849,
#  'завтра': 163974,
#  'самого': 250093,
#  'спектакли': 260126,
#  'квартета': 177243,
#  'ска': 254324,
#  'ебаная': 159841,
#  'погода': 224639,
#  'краши': 183000,
#  'планы': 223044,
#  'пух': 241336,
#  'прах': 233566,
#  'пожаалуйста': 226827,
#  'lera_pinaeva': 63703,
#  'дурочка': 159168,
#  'нафиг': 201633,
#  'организм': 212793,
#  'портишь': 230743,
#  'сходили': 264647,
#  'хоббиты': 282589,
#  'пустошь': 241183,
#  'смауга': 256507,
#  'крутой': 183907,
#  'облом': 208353,
#  'конце': 181085,
#  'расстроил': 245191,
#  'нервно': 204484,
#  'ждать': 161597,
#  'продолжения': 238076,
#  'кинонаркоман': 177978,
#  'sashapetrova23': 95137,
#  'ахаххахахах': 127452,
#  'видела': 139233,
#  'смотрю': 256942,
#  'оплату': 212278,
#  'труда': 271088,
#  'антимайдане': 125456,
#  'итоге': 174344,
#  'люди': 189437,
#  'приходят': 236886,
#  'євромайдан': 293954,
#  'поесть': 226801,
#  'уехать': 274039,
#  'домой': 157331,
#  'деньги': 153987,
#  'платят': 223192,
#  'своих': 251651,
#  'воруют': 142124,
#  'agnesell': 11766,
#  'согластен': 258056,
#  'поносью': 229643,
#  'культовая': 184527,
#  'сага': 249727,
#  'о_о': 207580,
#  'одну': 210691,
#  'серию': 253170,
#  'сдюжил': 252190,
#  'стареньке': 261761,
#  'воще': 142554,
#  'чушь': 287695,
#  'вся': 143654,
#  'моя': 196349,
#  'сущность': 264517,
#  'одной': 210600,
#  'картинке': 176499,
#  'h1gmzmjcaq': 45044,
#  'отправил': 215534,
#  'тимлиду': 268525,
#  'перловщиков': 221108,
#  'микропатч': 193741,
#  'хреново': 283542,
#  'заинвалидит': 165134,
#  'хохохо': 283350,
#  'эт': 291943,
#  'молодцы': 195478,
#  'бунт': 135397,
#  'устроили': 276778,
#  'достала': 157945,
#  'физичка': 278906,
#  'offspring': 81578,
#  'kristi': 60333,
#  'are': 18005,
#  'you': 118491,
#  'doing': 33075,
#  'okay': 81880,
#  'никогда': 205525,
#  'перестанет': 220813,
#  'нравиться': 206940,
#  'напоминать': 200203,
#  'владика': 140345,
#  'стыдно': 263523,
#  'наорала': 199963,
#  'гея': 148109,
#  'alimansarov': 13667,
#  'cio_optimal': 26526,
#  'плохой': 223558,
#  'тоже': 268991,
#  'орион': 212955,
#  'дома': 157218,
#  'расстроилась': 245193,
#  'какая': 175282,
#  'прелесть': 234398,
#  'толстая': 269170,
#  'qqx5wda0z1': 89595,
#  'mizypisoroq': 73066,
#  'телеку': 267508,
#  'квартал': 177232,
#  '95': 7643,
#  'пригласили': 235140,
#  'чайф': 285536,
#  'догадались': 156463,
#  'киркоров': 178144,
#  'моисеев': 195278,
#  'вообщ': 141872,
#  'ksenya1510': 60920,
#  'сомневалась': 258675,
#  'давай': 151986,
#  'nyushacom': 80881,
#  'нюша': 207402,
#  'самая': 250035,
#  'одна': 210517,
#  'обожаю': 208760,
#  'тебя': 267314,
#  'сильно': 253786,
#  'повсюду': 224377,
#  'пролезут': 238763,
#  'тараканы': 266515,
#  'followback': 40111,
#  'obe_1_kanobe_vz': 81258,
#  'аха': 127144,
#  'шлюхе': 289194,
#  'березину': 130840,
#  'чью': 287732,
#  'телку': 267622,
#  'ебал': 159815,
#  'молодой': 195467,
#  'березин': 130838,
#  'терь': 268131,
#  'альбом': 124436,
#  'доделывает': 156597,
#  'бля': 132593,
#  'обратно': 209105,
#  'лагерь': 185574,
#  'промитей': 238884,
#  'смена': 256565,
#  'отряд': 215898,
#  'скучать': 255381,
#  'вожатыми': 141086,
#  'вадимом': 136517,
#  'денисом': 153954,
#  'печатай': 221565,
#  'смс': 256961,
#  'хочешь': 283386,
#  'любовью': 189360,
#  'follow': 40104,
#  'читаю': 286963,
#  'event': 37644,
#  'bubbling': 23910,
#  'просачивание': 239298,
#  'события': 257774,
#  'перевести': 219612,
#  'хватает': 281784,
#  'черт': 286325,
#  'спела': 260138,
#  'одноголосия': 210556,
#  'еле': 160659,
#  'разговариваю': 242965,
#  'долбаный': 157016,
#  'недосып': 202885,
#  'forever_masya': 40249,
#  'снято': 257490,
#  'хуже': 283928,
#  '10': 682,
#  'сожалению': 258181,
#  'маленька': 190524,
#  'буде': 135019,
#  'добре': 156209,
#  'потрібно': 232280,
#  'убиватись': 272760,
#  'він': 146770,
#  'цього': 285375,
#  'вартий': 137087,
#  'omujibogap': 82943,
#  'господь': 150138,
#  'позволил': 227108,
#  'встретится': 143526,
#  'знал': 170126,
#  'будем': 135026,
#  'вместе': 140643,
#  'iil9yrpcpi': 49112,
#  'klyushina_yulya': 58784,
#  'родители': 247863,
#  'концерте': 181109,
#  'alexchumakoff': 13266,
#  'воронеже': 142069,
#  'приятного': 237088,
#  'alfgala': 13531,
#  'nata_klyushina': 77443,
#  'erro_de_memoria': 37149,
#  'лол': 188325,
#  'нарисую': 200518,
#  'портрет': 230751,
#  'фрэнка': 280420,
#  'листочке': 187732,
#  'карикатурка': 176308,
#  'blueyellowgay': 22753,
#  'без': 130005,
#  'проблем': 237244,
#  'считать': 264898,
#  'свадебной': 251014,
#  'клятвой': 179070,
#  'boo_ohoo': 23146,
#  'super_batman_': 101184,
#  'думай': 158973,
#  'парни': 218315,
#  'анорексичек': 125389,
#  'privovet': 87860,
#  'askhabwolf': 18846,
#  'острый': 213780,
#  'homtanya': 47068,
#  'посмотрела': 231314,
#  'пришлось': 237037,
#  'уйти': 274402,
#  'слушаю': 256315,
#  'музыку': 196769,
#  'учебе': 277519,
#  'эту': 292090,
#  'четверть': 286506,
#  'плохо': 223551,
#  'закончу': 165637,
#  'капец': 175995,
#  'хожу': 282694,
#  'слезах': 255750,
#  'терпеть': 268064,
#  'помогите': 229299,
#  'прошу': 240337,
#  'xoxo_oleenom': 116378,
#  'пришел': 237000,
#  'делишки': 153756,
#  'наивный': 199081,
#  'планировал': 222963,
#  'круглый': 183748,
#  'стол': 262534,
#  'мгд': 192317,
#  'приехать': 235496,
#  'пипец': 222311,
#  'давно': 152051,
#  'температуры': 267772,
#  'бывало': 135823,
#  'lihvrfmqyo': 64623,
#  'cuvatufysoq': 28066,
#  'скала': 254466,
#  'idea': 48655,
#  'довольно': 156431,
#  'паршиво': 218476,
#  'поддерживается': 225169,
#  'говорят': 149102,
#  'эклипсе': 290824,
#  'выбора': 144214,
#  'особо': 213466,
#  'gorgadze_shota': 43706,
#  'жива': 162113,
#  'система': 254209,
#  'дракон': 158387,
#  'умрет': 275296,
#  'холодно': 282849,
#  'этом': 292055,
#  'вашем': 137322,
#  'екатеринбурге': 160608,
#  'ставропольский': 261484,
#  'край': 182655,
#  'рядом': 249541,
#  'захотел': 168673,
#  'поехал': 226813,
#  'кисловодск': 178255,
#  'ставрополь': 261482,
#  'ессентуки': 160988,
#  'часа': 285643,
#  'islobozhan': 51190,
#  'green_killj0y': 44097,
#  'ихихихих': 174411,
#  'спасиба': 259974,
#  'повалит': 224036,
#  'юп': 292606,
#  'развитый': 242807,
#  'рвотный': 245808,
#  'рефлекс': 247101,
#  'неприятная': 204348,
#  'штука': 289772,
#  'печаль': 221510,
#  'наркотик': 200572,
#  'услышала': 276424,
#  'ничего': 205838,
#  'хадорковского': 280955,
#  'удался': 273587,
#  'nzlobin': 80928,
#  'действительно': 153571,
#  'несколько': 204618,
#  'неожиданное': 203920,
#  'развитие': 242800,
#  'событий': 257771,
#  'dyyc3pmntl': 34408,
#  'утрррооо': 277133,
#  'туманноеее': 271466,
#  'утррррооо': 277134,
#  'седооооеее': 252350,
#  'nvolxixpvl': 80673,
#  'проспал': 239506,
#  'весь': 138508,
#  'нихуя': 205813,
#  'выспался': 146043,
#  'сука': 263848,
#  'ekaterina_just': 35638,
#  'такое': 266003,
#  ...}

# %%
vctr.vocabulary_.get('мимими')
# Out:
# 194050

# %% [markdown]
# ### 3.2. TF.IDF vectorizer

# %%
vctr_tfidf = sklearn.feature_extraction.text.TfidfTransformer()

# %%
X_train_counts_tfidf = vctr_tfidf.fit_transform(X_train_counts)

# %%
vctr_tfidf.idf_
# Out:
# array([  6.99515243,   8.36913353,  11.25253662, ...,  11.9456838 ,
#         11.9456838 ,  12.63883098])

# %%
vctr_tfidf.get_params()
# Out:
# {'norm': 'l2', 'smooth_idf': True, 'sublinear_tf': False, 'use_idf': True}

# %%
import sklearn.pipeline
import sklearn.naive_bayes

text_clf = sklearn.pipeline.Pipeline([('vect', sklearn.feature_extraction.text.CountVectorizer()),
                     ('clf', sklearn.naive_bayes.MultinomialNB())])

# %% [markdown]
# ## 4. Classifying

# %%
text_clf.fit(x_train["ttext"], y_train)
# Out:
# Pipeline(steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)), ('clf', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predicted = text_clf.predict(x_val["ttext"])

# %%
import sklearn.metrics
print(sklearn.metrics.classification_report(y_val, predicted, target_names=["negative", "positive"]))
# Out:
#              precision    recall  f1-score   support
#
#    negative       0.73      0.80      0.76     22168
#    positive       0.79      0.72      0.75     23199
#
# avg / total       0.76      0.76      0.76     45367

# %%
sklearn.metrics.confusion_matrix(y_val, predicted)
# Out:
# array([[17640,  4528],
#        [ 6521, 16678]])
