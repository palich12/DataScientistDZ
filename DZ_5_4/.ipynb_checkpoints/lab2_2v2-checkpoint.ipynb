# %% [markdown]
# ## Digit Recognizer
# https://www.kaggle.com/c/digit-recognizer

# %%
# %matplotlib inline
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Загружаем исходные данные

# %%
train_and_y = np.loadtxt('C:/temp/digit/train.csv', delimiter=',', skiprows=1)
test = np.loadtxt('C:/temp/digit/test.csv', delimiter=',', skiprows=1)

# %%
# сохраняем разметку в отдельную переменную
train_label = train_and_y[:, 0]
train=train_and_y[:, 1:]

# %%
# приводим размерность к удобному для обаботки виду
train_img = np.resize(train, (train.shape[0], 28, 28))
test_img = np.resize(test, (test.shape[0], 28, 28))

# %%
train.shape
# Out:
# (42000, 784)

# %%
train_img.shape
# Out:
# (42000, 28, 28)

# %% [markdown]
# ## Визуализируем исходные данные

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_img[0:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);

# %% [markdown]
# ## Вычисляем X и Y составляющие градиента с помощью оператора Собеля

# %%
train_sobel_x = np.zeros_like(train_img)
train_sobel_y = np.zeros_like(train_img)
for i in range(len(train_img)):
    train_sobel_x[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    train_sobel_y[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %%
test_sobel_x = np.zeros_like(test_img)
test_sobel_y = np.zeros_like(test_img)
for i in range(len(test_img)):
    test_sobel_x[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    test_sobel_y[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %% [markdown]
# ## Вычисляем угол и длину вектора градиента

# %%
train_g, train_theta = cv2.cartToPolar(train_sobel_x, train_sobel_y)

# %%
test_g, test_theta = cv2.cartToPolar(test_sobel_x, test_sobel_y)

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_g[:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);
    subplot = fig.add_subplot(3, 7, i)
    plt.hist(train_theta[i - 1].flatten(),
             bins=16, weights=train_g[i - 1].flatten())

# %% [markdown]
# ## Вычисляем гистограммы градиентов

# %%
hist_count = 100

# %%
# Гистограммы вычисляются с учетом длины вектора градиента
train_hist = np.zeros((len(train_img), hist_count*13))
for i in range(len(train_img)):
    hist0, borders0 = np.histogram(train_theta[i],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i])
    hist1, borders1 = np.histogram(train_theta[i][:13,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:13,:13])
    hist2, borders2 = np.histogram(train_theta[i][:13,13:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:13,13:])
    hist3, borders3 = np.histogram(train_theta[i][13:,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][13:,:13])
    hist4, borders4 = np.histogram(train_theta[i][:13,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:13,:13])
    hist5, borders5 = np.histogram(train_theta[i][:,:7],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:,:7])
    hist6, borders6 = np.histogram(train_theta[i][:,7:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:,7:13])
    hist7, borders7 = np.histogram(train_theta[i][:,13:21],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:,13:21])
    hist8, borders8 = np.histogram(train_theta[i][:,21:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:,21:])
    hist9, borders9 = np.histogram(train_theta[i][:7,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][:7,:])
    hist10, borders10 = np.histogram(train_theta[i][7:13,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][7:13,:])
    hist11, border11 = np.histogram(train_theta[i][13:21,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][13:21,:])
    hist12, borders12 = np.histogram(train_theta[i][21:,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i][21:,:])
    train_hist[i] = np.concatenate( (hist0,hist1,hist2,hist3,hist4,hist5,hist6,hist7,hist8,hist9,hist10,hist11,hist12), axis=0)

# %%
#Гистограммы вычисляются с учетом длины вектора градиента
test_hist = np.zeros((len(test_img), hist_count*13))
for i in range(len(test_img)):
    hist0, borders0 = np.histogram(test_theta[i],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i])
    hist1, borders1 = np.histogram(test_theta[i][:13,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:13,:13])
    hist2, borders2 = np.histogram(test_theta[i][:13,13:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:13,13:])
    hist3, borders3 = np.histogram(test_theta[i][13:,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][13:,:13])
    hist4, borders4 = np.histogram(test_theta[i][:13,:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:13,:13])
    hist5, borders5 = np.histogram(test_theta[i][:,:7],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:,:7])
    hist6, borders6 = np.histogram(test_theta[i][:,7:13],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:,7:13])
    hist7, borders7 = np.histogram(test_theta[i][:,13:21],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:,13:21])
    hist8, borders8 = np.histogram(test_theta[i][:,21:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:,21:])
    hist9, borders9 = np.histogram(test_theta[i][:7,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][:7,:])
    hist10, borders10 = np.histogram(test_theta[i][7:13,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][7:13,:])
    hist11, border11 = np.histogram(test_theta[i][13:21,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][13:21,:])
    hist12, borders12 = np.histogram(test_theta[i][21:,:],
                                 bins=hist_count,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i][21:,:])
    test_hist[i] = np.concatenate( (hist0,hist1,hist2,hist3,hist4,hist5,hist6,hist7,hist8,hist9,hist10,hist11,hist12), axis=0)

# %%
# train_hist = np.zeros((len(train_img), hist_count*4))
# for i in range(len(train_img)):
#     train_hist[i], borders = np.histogram(train_theta[i],
#                                  bins=hist_count*4,
#                                  range=(0., 2. * np.pi),
#                                  weights=train_g[i])

# %%
# test_hist = np.zeros((len(test_img), hist_count*4))
# for i in range(len(test_img)):
#     train_hist[i], borders = np.histogram(test_theta[i],
#                                  bins=hist_count*4,
#                                  range=(0., 2. * np.pi),
#                                  weights=test_g[i])

# %% [markdown]
# ## Нормируем вектор гистограммы

# %%
# По умолчанию используется L2 норма
train_hist = train_hist / np.linalg.norm(train_hist, axis=1)[:, None]

# %%
test_hist = test_hist / np.linalg.norm(test_hist, axis=1)[:, None]

# %% [markdown]
# ## Разбиваем выборку на обучение и валидацию

# %%
from sklearn.model_selection import train_test_split
y_train, y_val, x_train, x_val = train_test_split(train_label, train_hist, test_size=0.2, random_state=42)
#y_train, y_val, x_train, x_val = train_test_split(train_label, train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Собираем полносвязную сеть для обучения

# %%
x_train.shape
# Out:
# (33600, 1300)

# %%
model = keras.models.Sequential()
n = x_train.shape[1]*2
model.add(keras.layers.Dense(n, input_dim=x_train.shape[1], activation='relu'))
model.add(keras.layers.Dense(n, activation='relu'))
#model.add(keras.layers.Dense(n, activation='relu'))
#model.add(keras.layers.Dense(n, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Выводим информацию о модели

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 2600)              3382600
# _________________________________________________________________
# dense_22 (Dense)             (None, 2600)              6762600
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                26010
# =================================================================
# Total params: 10,171,210
# Trainable params: 10,171,210
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## One hot encoding разметки

# %%
from keras.utils import np_utils
y_train_labels = np_utils.to_categorical(y_train)
print( y_train.shape, y_train_labels.shape, x_train.shape)
# Out:
# (33600,) (33600, 10) (33600, 1300)

# %% [markdown]
# ## Запускаем обучение

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
epochs_count = 20
for i in range(epochs_count):
    print('------ Epoch %s ------' % (i+1))
    model.fit(x_train, y_train_labels, batch_size=840, epochs=1)
    pred_val = model.predict_classes(x_val)
    print('Accuracy: %s' % accuracy_score(y_val, pred_val))
    print(classification_report(y_val, pred_val))
    print(confusion_matrix(y_val, pred_val))
# Out:
# ------ Epoch 1 ------
# Epoch 1/1
# 33600/33600 [==============================] - 68s - loss: 0.5494 - acc: 0.8462
# 8400/8400 [==============================] - 8s
# Accuracy: 0.946904761905
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.96      0.97       816
#         1.0       0.96      0.99      0.98       909
#         2.0       0.94      0.95      0.95       846
#         3.0       0.95      0.94      0.94       937
#         4.0       0.95      0.97      0.96       839
#         5.0       0.96      0.93      0.95       702
#         6.0       0.93      0.98      0.95       785
#         7.0       0.96      0.95      0.96       893
#         8.0       0.94      0.85      0.89       835
#         9.0       0.89      0.95      0.92       838
#
# avg / total       0.95      0.95      0.95      8400
#
# [[783   5   1   0   3   1  13   0   4   6]
#  [  0 900   3   1   1   0   3   1   0   0]
#  [  1  12 804   6   8   0   2   2   8   3]
#  [  0   0  24 879   0   5   1   9  10   9]
#  [  1   4   0   0 812   0   4   0   2  16]
#  [  0   0   2  21   1 656   6   2  12   2]
#  [  1   3   0   0   9   2 768   0   2   0]
#  [  0   3   5   3   3   0   0 845   5  29]
#  [  4   8  12  12   3  19  27   7 711  32]
#  [  2   1   3   3  16   2   0  10   5 796]]
# ------ Epoch 2 ------
# Epoch 1/1
# 33600/33600 [==============================] - 66s - loss: 0.1250 - acc: 0.9601
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.961547619048
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.98      0.98       816
#         1.0       0.99      0.98      0.99       909
#         2.0       0.95      0.97      0.96       846
#         3.0       0.95      0.96      0.96       937
#         4.0       0.97      0.97      0.97       839
#         5.0       0.98      0.94      0.96       702
#         6.0       0.96      0.98      0.97       785
#         7.0       0.97      0.94      0.96       893
#         8.0       0.93      0.93      0.93       835
#         9.0       0.93      0.96      0.94       838
#
# avg / total       0.96      0.96      0.96      8400
#
# [[798   0   4   0   1   0  10   1   1   1]
#  [  1 895   5   0   2   0   3   3   0   0]
#  [  0   1 823   8   6   0   0   1   5   2]
#  [  0   0  10 904   0   3   1   6   9   4]
#  [  1   0   1   0 810   0   5   1   3  18]
#  [  1   0   0  17   0 657   5   1  20   1]
#  [  5   2   0   0   5   1 768   0   4   0]
#  [  0   2  12   6   1   0   0 839   6  27]
#  [  5   1   8  11   1   5  11   3 779  11]
#  [  2   0   2   5   7   2   0   9   7 804]]
# ------ Epoch 3 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0850 - acc: 0.9730
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.964166666667
#              precision    recall  f1-score   support
#
#         0.0       0.97      1.00      0.98       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.95      0.98      0.96       846
#         3.0       0.97      0.95      0.96       937
#         4.0       0.97      0.98      0.97       839
#         5.0       0.99      0.94      0.96       702
#         6.0       0.96      0.98      0.97       785
#         7.0       0.97      0.96      0.96       893
#         8.0       0.97      0.90      0.93       835
#         9.0       0.92      0.97      0.94       838
#
# avg / total       0.96      0.96      0.96      8400
#
# [[812   0   0   0   1   0   3   0   0   0]
#  [  1 896   2   0   1   0   4   4   0   1]
#  [  1   1 829   0   7   0   3   2   2   1]
#  [  2   0  19 891   0   3   1   9   5   7]
#  [  1   0   0   0 819   0   5   1   0  13]
#  [  2   0   3  16   0 660   6   1  13   1]
#  [  5   1   0   0   6   1 769   0   3   0]
#  [  0   1  11   2   2   0   0 854   2  21]
#  [  6   1  11   8   5   5  11   5 755  28]
#  [  4   0   2   2   6   1   0   8   1 814]]
# ------ Epoch 4 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0603 - acc: 0.9820
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.965357142857
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.97      0.98       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.94      0.99      0.96       846
#         3.0       0.98      0.95      0.96       937
#         4.0       0.98      0.97      0.97       839
#         5.0       0.95      0.97      0.96       702
#         6.0       0.95      0.98      0.96       785
#         7.0       0.98      0.95      0.96       893
#         8.0       0.96      0.92      0.94       835
#         9.0       0.93      0.97      0.95       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[794   1   5   1   1   0  11   1   1   1]
#  [  1 901   1   0   1   0   4   1   0   0]
#  [  0   1 834   1   3   0   1   2   3   1]
#  [  0   0  15 890   0  10   2   6   8   6]
#  [  1   0   0   0 814   0   5   1   0  18]
#  [  0   0   1   6   0 681   7   1   5   1]
#  [  2   1   0   0   5   3 771   0   3   0]
#  [  0   2  15   4   3   0   0 845   3  21]
#  [  4   1  12   6   1  15  13   3 767  13]
#  [  1   0   1   3   5   5   0   6   5 812]]
# ------ Epoch 5 ------
# Epoch 1/1
# 33600/33600 [==============================] - 66s - loss: 0.0432 - acc: 0.9874
# 8400/8400 [==============================] - 10s
# Accuracy: 0.9675
#              precision    recall  f1-score   support
#
#         0.0       0.98      0.99      0.98       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.96      0.98      0.97       846
#         3.0       0.96      0.96      0.96       937
#         4.0       0.99      0.96      0.98       839
#         5.0       0.99      0.95      0.97       702
#         6.0       0.96      0.98      0.97       785
#         7.0       0.98      0.94      0.96       893
#         8.0       0.94      0.95      0.94       835
#         9.0       0.93      0.97      0.95       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[807   0   2   1   0   0   4   0   1   1]
#  [  1 897   2   0   0   0   3   5   0   1]
#  [  0   0 830   3   2   0   2   2   7   0]
#  [  1   0   7 904   0   2   1   5  12   5]
#  [  1   1   2   0 809   0   5   1   2  18]
#  [  1   0   1  14   0 666   5   0  14   1]
#  [  5   1   0   0   4   1 770   0   4   0]
#  [  0   1  14   6   2   1   0 840   5  24]
#  [  5   0   6   6   0   2   9   3 794  10]
#  [  2   0   0   5   3   3   0   5  10 810]]
# ------ Epoch 6 ------
# Epoch 1/1
# 33600/33600 [==============================] - 68s - loss: 0.0273 - acc: 0.9933
# 8400/8400 [==============================] - 8s
# Accuracy: 0.969761904762
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.98      0.98       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.97      0.98      0.97       846
#         3.0       0.98      0.96      0.97       937
#         4.0       0.98      0.97      0.98       839
#         5.0       0.98      0.96      0.97       702
#         6.0       0.95      0.99      0.97       785
#         7.0       0.97      0.96      0.96       893
#         8.0       0.94      0.96      0.95       835
#         9.0       0.96      0.95      0.95       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[802   0   2   1   0   0   9   0   1   1]
#  [  1 900   0   0   0   0   5   2   1   0]
#  [  1   0 827   1   3   0   2   2   9   1]
#  [  0   0  12 895   0   7   2   6  10   5]
#  [  1   3   1   0 814   0   6   3   1  10]
#  [  0   0   1   5   0 677   6   0  12   1]
#  [  2   1   0   0   3   1 775   0   3   0]
#  [  0   2   9   3   3   1   0 858   5  12]
#  [  3   1   3   4   0   5   9   3 800   7]
#  [  3   0   0   3   7   3   0  13  11 798]]
# ------ Epoch 7 ------
# Epoch 1/1
# 33600/33600 [==============================] - 61s - loss: 0.0199 - acc: 0.9956
# 8352/8400 [============================>.] - ETA: 0sAccuracy: 0.969285714286
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.98      0.98       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.95      0.98      0.97       846
#         3.0       0.98      0.95      0.97       937
#         4.0       0.98      0.98      0.98       839
#         5.0       0.98      0.96      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.96      0.96      0.96       893
#         8.0       0.93      0.97      0.95       835
#         9.0       0.96      0.95      0.95       838
#
# avg / total       0.97      0.97      0.97      8400
# [[802   0   4   1   0   0   5   1   2   1]
#  [  1 898   1   0   0   0   3   6   0   0]
#  [  0   0 830   1   3   1   1   2   8   0]
#  [  0   0  16 889   0   4   1   8  16   3]
#  [  1   1   3   0 819   0   5   2   1   7]
#  [  2   0   1   5   0 677   3   0  13   1]
#  [  5   1   1   0   5   2 767   0   4   0]
#  [  0   2  10   2   3   0   0 861   4  11]
#  [  2   1   4   4   0   3   5   3 806   7]
#  [  1   0   0   3   8   5   0  15  13 793]]
# ------ Epoch 8 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0125 - acc: 0.9980
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.971428571429
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.98      0.98       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.97      0.98       846
#         3.0       0.98      0.96      0.97       937
#         4.0       0.97      0.98      0.97       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.97      0.97       785
#         7.0       0.96      0.97      0.97       893
#         8.0       0.94      0.96      0.95       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[801   0   2   1   1   0   7   1   2   1]
#  [  1 898   0   0   1   0   3   4   1   1]
#  [  0   0 824   3   5   1   1   3   9   0]
#  [  0   0   5 904   0   6   1   7  10   4]
#  [  1   2   1   0 820   0   5   1   2   7]
#  [  1   0   1   5   0 680   3   0  11   1]
#  [  4   2   1   0  10   2 762   0   4   0]
#  [  0   1   3   3   3   1   0 866   4  12]
#  [  2   1   2   6   1   3   4   3 804   9]
#  [  2   0   0   2   7   3   0  13  10 801]]
# ------ Epoch 9 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0098 - acc: 0.9988
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.971428571429
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.98      0.99       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.97      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.98      0.97      0.97       839
#         5.0       0.96      0.97      0.97       702
#         6.0       0.97      0.98      0.98       785
#         7.0       0.97      0.96      0.97       893
#         8.0       0.95      0.95      0.95       835
#         9.0       0.95      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[802   0   2   1   0   0   7   1   2   1]
#  [  1 899   1   0   1   0   3   3   0   1]
#  [  0   0 830   3   3   1   1   2   6   0]
#  [  0   0   6 904   0   9   1   6   7   4]
#  [  1   1   3   0 816   0   5   2   1  10]
#  [  1   0   1   5   0 682   2   0  10   1]
#  [  2   1   0   0   5   3 770   0   4   0]
#  [  0   1   6   6   4   1   0 857   3  15]
#  [  2   1   6   9   1   8   5   3 792   8]
#  [  1   0   0   6   5   4   0   7   7 808]]
# ------ Epoch 10 ------
# Epoch 1/1
# 33600/33600 [==============================] - 67s - loss: 0.0054 - acc: 0.9998
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.97119047619
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.97      0.98      0.97       846
#         3.0       0.98      0.95      0.97       937
#         4.0       0.98      0.96      0.97       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.96      0.97      0.96       893
#         8.0       0.95      0.96      0.95       835
#         9.0       0.93      0.97      0.95       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[805   0   2   1   0   0   5   1   1   1]
#  [  1 898   0   0   0   0   3   5   1   1]
#  [  0   0 831   1   2   0   1   3   7   1]
#  [  0   0  12 892   0   6   1  10  11   5]
#  [  1   1   2   0 805   0   4   4   1  21]
#  [  1   0   2   5   0 680   3   0  10   1]
#  [  3   2   1   0   7   2 766   0   4   0]
#  [  0   1   6   2   2   0   0 864   3  15]
#  [  2   1   5   5   0   3   4   3 800  12]
#  [  2   0   0   1   3   3   0   8   4 817]]
# ------ Epoch 11 ------
# Epoch 1/1
# 33600/33600 [==============================] - 67s - loss: 0.0034 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973571428571
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.98      0.99       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.98      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.98       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[802   0   2   1   0   0   7   1   2   1]
#  [  1 900   0   0   0   0   3   4   1   0]
#  [  0   0 828   2   4   0   1   3   8   0]
#  [  0   0   7 900   0   7   1   7  11   4]
#  [  1   1   1   0 819   0   5   4   1   7]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  2   1   0   0   6   2 770   0   4   0]
#  [  0   1   4   4   3   0   0 869   3   9]
#  [  2   1   2   6   0   3   4   3 806   8]
#  [  2   0   0   5   7   3   0   9   7 805]]
# ------ Epoch 12 ------
# Epoch 1/1
# 33600/33600 [==============================] - 65s - loss: 0.0026 - acc: 0.9999
# 8400/8400 [==============================] - 10s
# Accuracy: 0.972738095238
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.96      0.97       893
#         8.0       0.94      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   2   1   0   0   6   0   2   1]
#  [  1 899   0   0   1   0   3   3   1   1]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   7 903   0   5   1   7  10   4]
#  [  1   1   1   0 820   0   5   2   1   8]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   7   2 768   0   4   0]
#  [  0   1   6   5   3   2   0 857   4  15]
#  [  2   1   2   6   0   3   4   3 807   7]
#  [  2   0   0   3   7   3   0   8   9 806]]
# ------ Epoch 13 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0022 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973928571429
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.99      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 827   2   4   1   1   3   8   0]
#  [  0   0   5 906   0   5   1   7   9   4]
#  [  1   1   1   0 820   0   5   3   1   7]
#  [  1   0   1   9   0 678   3   0   9   1]
#  [  3   1   0   0   7   2 768   0   4   0]
#  [  0   2   2   5   3   1   0 865   3  12]
#  [  2   1   2   6   0   3   4   3 807   7]
#  [  2   0   0   5   7   3   0   8   7 806]]
# ------ Epoch 14 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0020 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973333333333
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.96      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 827   2   4   1   1   3   8   0]
#  [  0   0   6 905   0   5   1   7   9   4]
#  [  1   1   1   0 820   0   5   3   1   7]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   2   0   0   7   2 767   0   4   0]
#  [  0   2   3   4   3   1   0 865   3  12]
#  [  2   2   2   6   0   3   4   3 805   8]
#  [  2   0   0   5   8   3   0   9   7 804]]
# ------ Epoch 15 ------
# Epoch 1/1
# 33600/33600 [==============================] - 63s - loss: 0.0018 - acc: 0.9999
# 8400/8400 [==============================] - 8s
# Accuracy: 0.97369047619
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.98      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.98       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.96      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[805   0   1   1   0   0   7   0   1   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 827   2   4   1   1   3   8   0]
#  [  0   0   6 905   0   5   1   7   9   4]
#  [  1   1   1   0 819   0   5   3   1   8]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   5   2 770   0   4   0]
#  [  0   1   4   4   3   1   0 864   3  13]
#  [  2   1   3   6   0   3   4   3 803  10]
#  [  2   0   0   5   7   3   0   8   6 807]]
# ------ Epoch 16 ------
# Epoch 1/1
# 33600/33600 [==============================] - 71s - loss: 0.0017 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973452380952
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       1.00      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   6 902   0   6   1   7  11   4]
#  [  1   1   1   0 821   0   5   3   1   6]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  2   1   0   0   7   2 769   0   4   0]
#  [  0   1   5   4   3   1   0 864   3  12]
#  [  2   1   2   6   0   3   4   3 807   7]
#  [  2   0   0   5   9   3   0   9   7 803]]
# ------ Epoch 17 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0016 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.97369047619
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   6 903   0   5   1   7  11   4]
#  [  1   1   1   0 820   0   5   3   1   7]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  2   1   0   0   7   2 769   0   4   0]
#  [  0   2   3   4   3   1   0 864   3  13]
#  [  2   1   2   6   0   3   4   3 807   7]
#  [  2   0   0   5   8   3   0   8   7 805]]
# ------ Epoch 18 ------
# Epoch 1/1
# 33600/33600 [==============================] - 65s - loss: 0.0015 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973571428571
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.96      0.97       937
#         4.0       0.98      0.98      0.98       839
#         5.0       0.97      0.97      0.97       702
#         6.0       0.97      0.98      0.98       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.96      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[805   0   1   1   0   0   7   0   1   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 827   2   4   1   1   3   8   0]
#  [  0   0   5 903   0   8   1   7   9   4]
#  [  1   1   1   0 819   0   5   3   1   8]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   5   2 770   0   4   0]
#  [  0   2   3   4   3   1   0 865   3  12]
#  [  2   1   2   6   0   5   4   3 804   8]
#  [  2   0   0   4   7   4   0   8   7 806]]
# ------ Epoch 19 ------
# Epoch 1/1
# 33600/33600 [==============================] - 63s - loss: 0.0014 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.973928571429
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.98      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.98       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.96      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[805   0   1   1   0   0   7   0   1   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   6 905   0   5   1   7   9   4]
#  [  1   1   1   0 819   0   5   3   1   8]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   5   2 770   0   4   0]
#  [  0   2   3   4   3   1   0 864   3  13]
#  [  2   1   2   6   0   4   4   3 805   8]
#  [  2   0   0   4   7   4   0   8   7 806]]
# ------ Epoch 20 ------
# Epoch 1/1
# 33600/33600 [==============================] - 62s - loss: 0.0014 - acc: 0.9999
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.97380952381
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   5 905   0   5   1   7  10   4]
#  [  1   1   1   0 820   0   5   3   1   7]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   7   2 768   0   4   0]
#  [  0   2   3   4   3   1   0 865   3  12]
#  [  2   1   2   6   0   3   4   3 806   8]
#  [  2   0   0   4   8   4   0   8   7 805]]

# %%
pred_val = model.predict_classes(x_val)
print('Accuracy: %s' % accuracy_score(y_val, pred_val))
print(classification_report(y_val, pred_val))
print(confusion_matrix(y_val, pred_val))
# Out:
# 8384/8400 [============================>.] - ETA: 0sAccuracy: 0.97380952381
#              precision    recall  f1-score   support
#
#         0.0       0.99      0.99      0.99       816
#         1.0       0.99      0.99      0.99       909
#         2.0       0.98      0.98      0.98       846
#         3.0       0.97      0.97      0.97       937
#         4.0       0.97      0.98      0.98       839
#         5.0       0.98      0.97      0.97       702
#         6.0       0.97      0.98      0.97       785
#         7.0       0.97      0.97      0.97       893
#         8.0       0.95      0.97      0.96       835
#         9.0       0.96      0.96      0.96       838
#
# avg / total       0.97      0.97      0.97      8400
#
# [[804   0   1   1   0   0   7   0   2   1]
#  [  1 900   0   0   1   0   3   3   1   0]
#  [  0   0 828   2   4   1   1   2   8   0]
#  [  0   0   5 905   0   5   1   7  10   4]
#  [  1   1   1   0 820   0   5   3   1   7]
#  [  1   0   1   8   0 679   3   0   9   1]
#  [  3   1   0   0   7   2 768   0   4   0]
#  [  0   2   3   4   3   1   0 865   3  12]
#  [  2   1   2   6   0   3   4   3 806   8]
#  [  2   0   0   4   8   4   0   8   7 805]]

# %% [markdown]
# ## Предсказания на тестовыйх данных

# %%
predicted_test = model.predict_classes(test_hist)
# Out:
# 28000/28000 [==============================] - 31s

# %%
predicted_test[0:7]
# Out:
# array([2, 0, 9, 8, 3, 7, 0], dtype=int64)

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(test_g[:7], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % predicted_test[i - 1]);
    subplot = fig.add_subplot(3, 7, i)
    plt.hist(test_theta[i - 1].flatten(), bins=16, weights=test_g[i - 1].flatten())

# %%
with open('submit.txt', 'w') as dst:
    dst.write('ImageId,Label\n')
    for i, p in enumerate(predicted_test, 1):
        dst.write('%s,%s\n' % (i, p))

# %% [markdown]
# # kaggle 0.97485
