# %% [markdown]
# ## Digit Recognizer
# https://www.kaggle.com/c/digit-recognizer

# %%
# %matplotlib inline
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Загружаем исходные данные

# %%
train = np.loadtxt('C:/temp/digit/train.csv', delimiter=',', skiprows=1)
test = np.loadtxt('C:/temp/digit/test.csv', delimiter=',', skiprows=1)

# %%
# сохраняем разметку в отдельную переменную
train_label = train[:, 0]
# приводим размерность к удобному для обаботки виду
train_img = np.resize(train[:, 1:], (train.shape[0], 28, 28))
test_img = np.resize(test, (test.shape[0], 28, 28))

# %% [markdown]
# ## Визуализируем исходные данные

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_img[0:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);

# %% [markdown]
# ## Вычисляем X и Y составляющие градиента с помощью оператора Собеля

# %%
train_sobel_x = np.zeros_like(train_img)
train_sobel_y = np.zeros_like(train_img)
for i in range(len(train_img)):
    train_sobel_x[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    train_sobel_y[i] = cv2.Sobel(train_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %%
test_sobel_x = np.zeros_like(test_img)
test_sobel_y = np.zeros_like(test_img)
for i in range(len(test_img)):
    test_sobel_x[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=1, dy=0, ksize=3)
    test_sobel_y[i] = cv2.Sobel(test_img[i], cv2.CV_64F, dx=0, dy=1, ksize=3)

# %% [markdown]
# ## Вычисляем угол и длину вектора градиента

# %%
train_g, train_theta = cv2.cartToPolar(train_sobel_x, train_sobel_y)

# %%
test_g, test_theta = cv2.cartToPolar(test_sobel_x, test_sobel_y)

# %%
fig = plt.figure(figsize=(20, 10))
for i, img in enumerate(train_g[:5], 1):
    subplot = fig.add_subplot(1, 7, i)
    plt.imshow(img, cmap='gray');
    subplot.set_title('%s' % train_label[i - 1]);
    subplot = fig.add_subplot(3, 7, i)
    plt.hist(train_theta[i - 1].flatten(),
             bins=16, weights=train_g[i - 1].flatten())

# %% [markdown]
# ## Вычисляем гистограммы градиентов

# %%
# Гистограммы вычисляются с учетом длины вектора градиента
train_hist = np.zeros((len(train_img), 16))
for i in range(len(train_img)):
    hist, borders = np.histogram(train_theta[i],
                                 bins=16,
                                 range=(0., 2. * np.pi),
                                 weights=train_g[i])
    train_hist[i] = hist

# %%
test_hist = np.zeros((len(test_img), 16))
for i in range(len(test_img)):
    hist, borders = np.histogram(test_theta[i],
                                 bins=16,
                                 range=(0., 2. * np.pi),
                                 weights=test_g[i])
    test_hist[i] = hist

# %% [markdown]
# ## Нормируем вектор гистограммы

# %%
# По умолчанию используется L2 норма
train_hist = train_hist / np.linalg.norm(train_hist, axis=1)[:, None]

# %%
test_hist = test_hist / np.linalg.norm(test_hist, axis=1)[:, None]

# %% [markdown]
# ## Разбиваем выборку на обучение и валидацию

# %%
from sklearn.model_selection import train_test_split
y_train, y_val, x_train, x_val = train_test_split(
    train_label, train_hist, test_size=0.2, random_state=42)

# %% [markdown]
# ## Проверим точность метода только на числе 5

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import r2_score
from sklearn.model_selection import KFold

from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import make_scorer

kfold = KFold(n_splits=4, shuffle=True, random_state=145)

# %% [markdown]
# Создадим ответы  только для числа 5

# %%
train_label
# Out:
# array([ 1.,  0.,  1., ...,  7.,  6.,  9.])

# %%
train_label_5 = train_label.copy()
i = 0
while i < len( train_label_5):
    train_label_5[i] = 1 if train_label_5[i] == 5 else 0
    i +=1
train_label_5
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
pipeline = Pipeline(steps=[('scale', StandardScaler()),
                           ('model', Ridge(alpha=1.0))])

param_grid = {'model': [Ridge(alpha=1.5),
                        RandomForestRegressor(),
                        GradientBoostingRegressor(),
                        BaggingRegressor()]}

grid = GridSearchCV(pipeline, param_grid, 
                    scoring=make_scorer(r2_score),
                    cv=kfold)
model = grid.fit(train_hist, train_label_5)
model.cv_results_['mean_test_score']
# Out:
# array([ 0.28169607,  0.38905764,  0.41859311,  0.38354981])

# %%
predicted_5 = model.best_estimator_.predict(train_hist)

pairs = np.array(sorted(zip(train_label_5, predicted_5)))
plt.plot(range(0, len(pairs)), pairs[:, 1], 'bo',
         range(0, len(pairs)), pairs[:, 0], 'r-')

plt.legend(['predicted', 'actual'])
plt.show()

# %%
error = 0
i = 0
while i < len( predicted_5):
    error += 1 if train_label_5[i] == 0 and predicted_5[i] > 0.5 or train_label_5[i] == 1 and predicted_5[i] <= 0.5 else 0
    i +=1
error / len( predicted_5)
# Out:
# 0.059095238095238097

# %% [markdown]
# ## Строим гибридную модель

# %%
y = []
for i in range(10):
    y_i = train_label.copy()
    j = 0
    for j in range(len( y_i)):
        y_i[j] = 1 if y_i[j] == i else 0
    y.append(y_i)
y
# Out:
# [array([ 0.,  1.,  0., ...,  0.,  0.,  0.]),
#  array([ 1.,  0.,  1., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  1.,  0.]),
#  array([ 0.,  0.,  0., ...,  1.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  array([ 0.,  0.,  0., ...,  0.,  0.,  1.])]

# %%
model = []
for i in range(10):
    pipeline = Pipeline(steps=[('scale', StandardScaler()),
                           ('model', Ridge(alpha=1.0))])
    param_grid = {'model': [Ridge(alpha=1.5),
                        RandomForestRegressor(),
                        GradientBoostingRegressor(),
                        BaggingRegressor()]}
    grid = GridSearchCV(pipeline, param_grid, 
                    scoring=make_scorer(r2_score),
                    cv=kfold)
    model.append( grid.fit(train_hist, y[i]))
    print("complite: ", i)
    print( model[i].cv_results_['mean_test_score'])
# Out:
# complite:  0
# [ 0.11276558  0.11864919  0.18775746  0.11470245]
# complite:  1
# [ 0.60550284  0.90957356  0.90848352  0.91112832]
# complite:  2
# [ 0.1091675   0.18251689  0.20845974  0.18010245]
# complite:  3
# [ 0.2564348   0.38238061  0.41513057  0.38580654]
# complite:  4
# [ 0.12117985  0.44483181  0.41727764  0.4498012 ]
# complite:  5
# [ 0.28169607  0.38315359  0.41863317  0.37683622]
# complite:  6
# [ 0.10683604  0.16867615  0.22996269  0.15854662]
# complite:  7
# [ 0.29919154  0.61812221  0.61067019  0.62091725]
# complite:  8
# [ 0.17805853  0.24449209  0.31095001  0.24749983]
# complite:  9
# [ 0.14324405  0.38292196  0.39951909  0.38697778]

# %%
for i in range(10):
    predicted = model[i].best_estimator_.predict(train_hist)
    pairs = np.array(sorted(zip(y[i], predicted)))
    plt.plot(range(0, len(pairs)), pairs[:, 1], 'bo',
         range(0, len(pairs)), pairs[:, 0], 'r-')
    plt.legend(['predicted ' + str(i), 'actual ' + str(i)])
    plt.show()

# %% [markdown]
# ## Вычисляем результат

# %%
import math

# %%
predicted_test_dif = []
for i in range(10):
    predicted_test_dif.append( model[i].best_estimator_.predict(test_hist))
    print("complite: ", i)
predicted_test_dif
# Out:
# complite:  0
# complite:  1
# complite:  2
# complite:  3
# complite:  4
# complite:  5
# complite:  6
# complite:  7
# complite:  8
# complite:  9
# [array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625]),
#  array([ 0.03412148, -0.01664029,  0.58977136, ...,  0.00765155,
#          0.45595971,  0.00184625])]

# %%
predicted_test = []
for i in range(len(test_hist)):
    max_j_index = 0
    max_j_val = predicted_test_dif[max_j_index][i]
    for j in range(10):
        if predicted_test_dif[j][i] > max_j_val:
            max_j_index = j
            max_j_val = predicted_test_dif[j][i]
        
    predicted_test.append(max_j_index)
predicted_test_norm[0:5]
# Out:
# [4, 4, 7, 4, 5]

# %%
with open('submit.txt', 'w') as dst:
    dst.write('ImageId,Label\n')
    for i, p in enumerate(predicted_test, 1):
        dst.write('%s,%s\n' % (i, p))
